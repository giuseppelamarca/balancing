# %%
from __future__ import division
#import numpy as np
import pickle
import rospy
import sys
from geometry_msgs.msg import Twist
from sensor_msgs.msg import Imu, JointState
from std_srvs.srv import Empty
from nav_msgs.msg import Odometry
from sensor_msgs.msg import LaserScan
from std_msgs.msg import Float32, Float64
import time
import pandas as pd
from matplotlib import pyplot as plt
from collections import deque
import random
import tensorflow as tf
import numpy as np

import torch
import torch.nn as nn
from torch.distributions import MultivariateNormal
import gym
import numpy as np

from gazebo_msgs.msg import ModelStates
from tensorboardX import SummaryWriter
import math

# %%
from collections import namedtuple
import numpy as np
from tensorboardX import SummaryWriter
import torch
import torch.nn as nn
import torch.optim as optim

# %%
wheel_l = "/self_balancing_ai/wheell_velocity_controller/command"
wheel_r = "/self_balancing_ai/wheelr_velocity_controller/command"


class SELF_BALANCING:
    def __init__(self):
        
        self.joint1 = rospy.Publisher(wheel_l,Float64,queue_size =1)
        self.joint2 = rospy.Publisher(wheel_r,Float64,queue_size =1)      
        
        self.joint1_msg = Float64()
        self.joint2_msg = Float64()    
    
        subscriber = rospy.Subscriber("/gazebo/model_states",ModelStates,callback=self.gazebo_callback)
        self.subscriber = rospy.Subscriber("/segway/joint_states",JointState,callback=self.robot_configuration_callback)
        self.subscriber = rospy.Subscriber("/imu",Imu,callback=self.imu_callback)
        self.subscriber = rospy.Subscriber("/segzay/laser/scan", LaserScan, callback=self.laser_callback)
        self.reset = rospy.ServiceProxy("/gazebo/reset_simulation",Empty)
        self.pause = rospy.ServiceProxy("/gazebo/pause_physics",Empty)
        self.unpause = rospy.ServiceProxy("/gazebo/unpause_physics",Empty)
        self.distance = 0
        self.tilt = 0
        self.postion = 0
        self.q = []
        self.roll = 0
        self.pitch= 0 
        self.yaw = 0 
        self.old_roll = 0
        self.robot_configuration = []

    def laser_callback(self,data):
        self.distance = data.ranges[0]
        
    def reset_pose(self):
            self.reset()
            Robot.joint1_msg.data = 0
            Robot.joint2_msg.data = 0
            
            Robot.joint1.publish(Robot.joint1_msg.data)
            Robot.joint2.publish(Robot.joint2_msg.data)  
            
            time.sleep(0.001)
            self.start_time = time.time()
            return Robot.get_state()
    
    def imu_callback(self, date):
        self.q = [
            date.orientation.x,
            date.orientation.y,
            date.orientation.z,
            date.orientation.w]
        x, y, z, w = self.q
        t0 = +2.0 * (w * x + y * z)
        t1 = +1.0 - 2.0 * (x * x + y * y)
        self.roll = math.atan2(t0, t1)
        t2 = +2.0 * (w * y - z * x)
        t2 = +1.0 if t2 > +1.0 else t2
        t2 = -1.0 if t2 < -1.0 else t2
        self.pitch = math.asin(t2)
        t3 = +2.0 * (w * z + x * y)
        t4 = +1.0 - 2.0 * (y * y + z * z)
        self.yaw = math.atan2(t3, t4)
    
    def execute_action(self, action1, action2):
        self.joint1_msg.data = action1
        self.joint2_msg.data = action2
        self.joint2.publish(self.joint1_msg.data)
        self.joint1.publish(self.joint2_msg.data) 
        
    def get_state(self):
        Ts = time.time() - self.start_time
        self.start_time = time.time()
        self.vel = (Robot.roll - self.old_roll)/Ts
        self.old_roll = Robot.roll
        return [self.roll,self.pitch, self.yaw, self.vel]
    
    def get_reward(self):
        return -abs(self.roll)
    
    def robot_configuration_callback(self, data):
        self.robot_configuration = data.position
        
    def gazebo_callback(self, data):
        self.position = data.pose[1].position.x

# %%
HIDDEN_SIZE = 128
BATCH_SIZE = 16
PERCENTILE = 70

# %%
class Net(nn.Module):
    def __init__(self, obs_size, hidden_size, n_actions):
        super(Net, self).__init__()
        self.net = nn.Sequential(
            nn.Linear(obs_size, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, n_actions)
        )

    def forward(self, x):
        return self.net(x)

# %%
rospy.init_node('self_balancing_dqn_ai',anonymous=True)
Robot = SELF_BALANCING()
Robot.reset_pose()
# Out:
# [0.0, 0.0, 0.0, 0.0]

# %%
obs_size = 4
n_actions = 80 #range(-10,10,1)

# %%
Episode = namedtuple('Episode', field_names=['reward', 'steps'])
EpisodeStep = namedtuple('EpisodeStep', field_names=['observation', 'action'])

def iterate_batches(net, batch_size):
    batch = []
    episode_reward = 0.0
    episode_steps = []
    obs = Robot.reset_pose()
    sm = nn.Softmax(dim=1)
    while True:
        obs_v = torch.FloatTensor([obs])
        act_probs_v = sm(net(obs_v))
        act_probs = act_probs_v.data.numpy()[0]
        action = np.random.choice(len(act_probs), p=act_probs) 
        action_robot = float(action - 40) / 4.0
        Robot.execute_action(action_robot, action_robot)
        next_obs = Robot.get_state()
        reward = Robot.get_reward()
        
        episode_reward += reward
        episode_steps.append(EpisodeStep(observation=obs, action=action))
        if abs(Robot.roll) > 0.6:
            batch.append(Episode(reward=episode_reward, steps=episode_steps))
            episode_reward = 0.0
            episode_steps = []
            next_obs = Robot.reset_pose()          
            if len(batch) == batch_size:
                yield batch
                batch = []
        obs = next_obs
        time.sleep(0.005)


def filter_batch(batch, percentile):
    rewards = list(map(lambda s: s.reward, batch))
    reward_bound = np.percentile(rewards, percentile)
    reward_mean = float(np.mean(rewards))

    train_obs = []
    train_act = []
    for example in batch:
        if example.reward < reward_bound:
            continue
        train_obs.extend(map(lambda step: step.observation, example.steps))
        train_act.extend(map(lambda step: step.action, example.steps))

    train_obs_v = torch.FloatTensor(train_obs)
    train_act_v = torch.LongTensor(train_act)
    return train_obs_v, train_act_v, reward_bound, reward_mean

# %%
    net = Net(obs_size, HIDDEN_SIZE, n_actions)
    objective = nn.CrossEntropyLoss()
    optimizer = optim.Adam(params=net.parameters(), lr=0.01)

    for iter_no, batch in enumerate(iterate_batches(net, BATCH_SIZE)):
        print("Iter: {}".format(iter_no))
        obs_v, acts_v, reward_b, reward_m = filter_batch(batch, PERCENTILE)
        optimizer.zero_grad()
        action_scores_v = net(obs_v)
        loss_v = objective(action_scores_v, acts_v)
        loss_v.backward()
        optimizer.step()

        print("%d: loss=%.3f, reward_mean=%.1f, reward_bound=%.1f" % (
            iter_no, loss_v.item(), reward_m, reward_b))
# Out:
# Iter: 0
# 0: loss=4.243, reward_mean=-13.4, reward_bound=-13.2
# Iter: 1
# 1: loss=4.158, reward_mean=-12.9, reward_bound=-12.2
# Iter: 2
# 2: loss=4.167, reward_mean=-12.8, reward_bound=-12.4
# Iter: 3
# 3: loss=4.027, reward_mean=-12.1, reward_bound=-11.6
# Iter: 4
# 4: loss=3.873, reward_mean=-12.1, reward_bound=-11.2
# Iter: 5
# 5: loss=3.742, reward_mean=-11.5, reward_bound=-11.0
# Iter: 6
# 6: loss=3.549, reward_mean=-10.9, reward_bound=-10.1
# Iter: 7
# 7: loss=3.247, reward_mean=-10.2, reward_bound=-9.2
# Iter: 8
# 8: loss=3.033, reward_mean=-10.2, reward_bound=-9.1
# Iter: 9
# 9: loss=2.685, reward_mean=-9.3, reward_bound=-8.9
# Iter: 10
# 10: loss=2.485, reward_mean=-8.8, reward_bound=-8.4
# Iter: 11
# 11: loss=2.396, reward_mean=-9.1, reward_bound=-8.7
# Iter: 12
# 12: loss=1.939, reward_mean=-8.5, reward_bound=-8.1
# Iter: 13
# 13: loss=1.903, reward_mean=-8.9, reward_bound=-8.4
# Iter: 14
# 14: loss=1.857, reward_mean=-8.1, reward_bound=-8.3
# Iter: 15
# 15: loss=1.611, reward_mean=-8.7, reward_bound=-8.2
# Iter: 16
# 16: loss=1.423, reward_mean=-8.2, reward_bound=-8.1
# Iter: 17
# 17: loss=1.588, reward_mean=-8.2, reward_bound=-8.0
# Iter: 18
# 18: loss=1.330, reward_mean=-8.6, reward_bound=-8.2
# Iter: 19
# 19: loss=1.383, reward_mean=-8.1, reward_bound=-7.5
# Iter: 20
# 20: loss=1.248, reward_mean=-7.9, reward_bound=-7.3
# Iter: 21
# 21: loss=1.504, reward_mean=-8.3, reward_bound=-6.9
# Iter: 22
# 22: loss=1.668, reward_mean=-7.8, reward_bound=-7.3
# Iter: 23
# 23: loss=1.595, reward_mean=-8.4, reward_bound=-7.9
# Iter: 24
# 24: loss=1.734, reward_mean=-8.4, reward_bound=-7.8
# Iter: 25
# 25: loss=1.920, reward_mean=-9.3, reward_bound=-8.9
# Iter: 26
# 26: loss=1.734, reward_mean=-8.5, reward_bound=-8.0
# Iter: 27
# 27: loss=1.469, reward_mean=-7.9, reward_bound=-7.2
# Iter: 28
# 28: loss=1.345, reward_mean=-7.5, reward_bound=-7.1
# Iter: 29
# 29: loss=1.243, reward_mean=-8.0, reward_bound=-7.8
# Iter: 30
# 30: loss=1.050, reward_mean=-7.9, reward_bound=-7.5
# Iter: 31
# 31: loss=0.893, reward_mean=-8.1, reward_bound=-8.3
# Iter: 32
# 32: loss=0.753, reward_mean=-8.3, reward_bound=-8.3
# Iter: 33
# 33: loss=0.832, reward_mean=-8.2, reward_bound=-8.3
# Iter: 34
# 34: loss=0.784, reward_mean=-8.0, reward_bound=-8.1
# Iter: 35
# 35: loss=0.494, reward_mean=-8.3, reward_bound=-8.2
# Iter: 36
# 36: loss=0.788, reward_mean=-8.0, reward_bound=-7.8
# Iter: 37
# 37: loss=0.402, reward_mean=-8.2, reward_bound=-8.2
# Iter: 38
# 38: loss=0.980, reward_mean=-7.8, reward_bound=-7.4
# Iter: 39
# 39: loss=0.699, reward_mean=-7.7, reward_bound=-6.8
# Iter: 40
# 40: loss=0.700, reward_mean=-7.8, reward_bound=-7.2
# Iter: 41
# 41: loss=0.726, reward_mean=-7.5, reward_bound=-7.0
# Iter: 42
# 42: loss=0.972, reward_mean=-7.5, reward_bound=-7.2
# Iter: 43
# 43: loss=1.080, reward_mean=-7.8, reward_bound=-7.5
# Iter: 44
# 44: loss=1.034, reward_mean=-7.8, reward_bound=-7.2
# Iter: 45
# 45: loss=1.042, reward_mean=-8.2, reward_bound=-7.5
# Iter: 46
# 46: loss=0.876, reward_mean=-7.9, reward_bound=-7.3
# Iter: 47
# 47: loss=0.664, reward_mean=-7.4, reward_bound=-6.9
# Iter: 48
# 48: loss=0.553, reward_mean=-7.6, reward_bound=-7.0
# Iter: 49
# 49: loss=0.550, reward_mean=-8.0, reward_bound=-7.9
# Iter: 50
# 50: loss=0.408, reward_mean=-7.7, reward_bound=-7.4
# Iter: 51
# 51: loss=0.308, reward_mean=-8.1, reward_bound=-8.1
# Iter: 52
# 52: loss=0.526, reward_mean=-8.0, reward_bound=-8.1
# Iter: 53
# 53: loss=0.311, reward_mean=-8.1, reward_bound=-8.2
# Iter: 54
# 54: loss=0.490, reward_mean=-8.0, reward_bound=-8.1
# Iter: 55
# 55: loss=0.619, reward_mean=-7.8, reward_bound=-7.5
# Iter: 56
# 56: loss=0.409, reward_mean=-7.6, reward_bound=-7.3
# Iter: 57
# 57: loss=0.497, reward_mean=-7.9, reward_bound=-7.5
# Iter: 58
# 58: loss=0.560, reward_mean=-7.4, reward_bound=-6.8
# Iter: 59
# 59: loss=0.648, reward_mean=-7.3, reward_bound=-6.7
# Iter: 60
# 60: loss=0.654, reward_mean=-7.5, reward_bound=-6.9
# Iter: 61
# 61: loss=0.921, reward_mean=-8.0, reward_bound=-7.2
# Iter: 62
# 62: loss=0.979, reward_mean=-8.7, reward_bound=-7.9
# Iter: 63
# 63: loss=1.048, reward_mean=-9.0, reward_bound=-8.5
# Iter: 64
# 64: loss=0.706, reward_mean=-8.1, reward_bound=-7.7
# Iter: 65
# 65: loss=0.578, reward_mean=-7.7, reward_bound=-7.0
# Iter: 66
# 66: loss=0.496, reward_mean=-7.1, reward_bound=-6.5
# Iter: 67
# 67: loss=0.512, reward_mean=-7.6, reward_bound=-7.0
# Iter: 68
# 68: loss=0.516, reward_mean=-7.7, reward_bound=-7.3
# Iter: 69
# 69: loss=0.420, reward_mean=-8.0, reward_bound=-8.2
# Iter: 70
# 70: loss=0.602, reward_mean=-7.7, reward_bound=-7.2
# Iter: 71
# 71: loss=0.571, reward_mean=-8.0, reward_bound=-8.2
# Iter: 72
# 72: loss=0.472, reward_mean=-7.8, reward_bound=-7.8
# Iter: 73
# 73: loss=0.346, reward_mean=-7.9, reward_bound=-7.6
# Iter: 74
# 74: loss=0.629, reward_mean=-7.8, reward_bound=-7.4
# Iter: 75
# 75: loss=0.438, reward_mean=-7.9, reward_bound=-8.0
# Iter: 76
# 76: loss=0.324, reward_mean=-7.4, reward_bound=-6.6
# Iter: 77
# 77: loss=0.381, reward_mean=-7.8, reward_bound=-7.8
# Iter: 78
# 78: loss=0.575, reward_mean=-7.3, reward_bound=-6.5
# Iter: 79
# 79: loss=0.473, reward_mean=-7.0, reward_bound=-6.5
# Iter: 80
# 80: loss=0.687, reward_mean=-7.1, reward_bound=-6.8
# Iter: 81
# 81: loss=0.534, reward_mean=-7.2, reward_bound=-6.8
# Iter: 82
# 82: loss=0.695, reward_mean=-7.6, reward_bound=-7.3
# Iter: 83
# 83: loss=0.581, reward_mean=-7.5, reward_bound=-7.1
# Iter: 84
# 84: loss=0.733, reward_mean=-7.5, reward_bound=-6.9
# Iter: 85
# 85: loss=0.563, reward_mean=-6.9, reward_bound=-6.2
# Iter: 86
# 86: loss=0.456, reward_mean=-6.9, reward_bound=-6.5
# Iter: 87
# 87: loss=0.551, reward_mean=-7.2, reward_bound=-6.6
# Iter: 88
# 88: loss=0.472, reward_mean=-6.8, reward_bound=-6.5
# Iter: 89
# 89: loss=0.538, reward_mean=-7.1, reward_bound=-6.9
# Iter: 90
# 90: loss=0.328, reward_mean=-7.2, reward_bound=-6.6
# Iter: 91
# 91: loss=0.582, reward_mean=-7.5, reward_bound=-6.7
# Iter: 92
# 92: loss=0.517, reward_mean=-7.6, reward_bound=-7.1
# Iter: 93
# 93: loss=0.284, reward_mean=-7.3, reward_bound=-6.7
# Iter: 94
# 94: loss=0.291, reward_mean=-7.5, reward_bound=-6.6
# Iter: 95
# 95: loss=0.331, reward_mean=-7.6, reward_bound=-7.0
# Iter: 96
# 96: loss=0.298, reward_mean=-7.8, reward_bound=-7.8
# Iter: 97
# 97: loss=0.361, reward_mean=-7.7, reward_bound=-7.0
# Iter: 98
# 98: loss=0.314, reward_mean=-7.8, reward_bound=-7.7
# Iter: 99
# 99: loss=0.415, reward_mean=-7.5, reward_bound=-7.0
# Iter: 100
# 100: loss=0.359, reward_mean=-7.8, reward_bound=-7.4
# Iter: 101
# 101: loss=0.458, reward_mean=-7.5, reward_bound=-7.1
# Iter: 102
# 102: loss=0.361, reward_mean=-7.4, reward_bound=-6.8
# Iter: 103
# 103: loss=0.444, reward_mean=-7.6, reward_bound=-7.1
# Iter: 104
# 104: loss=0.314, reward_mean=-7.1, reward_bound=-6.5
# Iter: 105
# 105: loss=0.498, reward_mean=-7.1, reward_bound=-6.5
# Iter: 106
# 106: loss=0.523, reward_mean=-6.9, reward_bound=-6.3
# Iter: 107
# 107: loss=0.528, reward_mean=-7.1, reward_bound=-6.7
# Iter: 108
# 108: loss=0.429, reward_mean=-6.8, reward_bound=-6.5
# Iter: 109
# 109: loss=0.486, reward_mean=-6.9, reward_bound=-6.6
# Iter: 110
# 110: loss=0.454, reward_mean=-7.3, reward_bound=-7.0
# Iter: 111
# 111: loss=0.458, reward_mean=-7.2, reward_bound=-6.9
# Iter: 112
# 112: loss=0.571, reward_mean=-6.8, reward_bound=-6.6
# Iter: 113
# 113: loss=0.467, reward_mean=-7.3, reward_bound=-7.0
# Iter: 114
# 114: loss=0.573, reward_mean=-6.9, reward_bound=-6.4
# Iter: 115
# 115: loss=0.591, reward_mean=-6.9, reward_bound=-6.5
# Iter: 116
# 116: loss=0.628, reward_mean=-6.9, reward_bound=-6.5
# Iter: 117
# 117: loss=0.534, reward_mean=-6.9, reward_bound=-6.4
# Iter: 118
# 118: loss=0.615, reward_mean=-7.2, reward_bound=-6.6
# Iter: 119
# 119: loss=0.575, reward_mean=-7.2, reward_bound=-6.5
# Iter: 120
# 120: loss=0.776, reward_mean=-7.4, reward_bound=-6.6
# Iter: 121
# 121: loss=0.730, reward_mean=-7.2, reward_bound=-6.5
# Iter: 122
# 122: loss=0.700, reward_mean=-7.9, reward_bound=-7.9
# Iter: 123
# 123: loss=0.569, reward_mean=-7.8, reward_bound=-7.6
# Iter: 124
# 124: loss=0.565, reward_mean=-7.2, reward_bound=-6.7
# Iter: 125
# 125: loss=0.654, reward_mean=-7.4, reward_bound=-6.9
# Iter: 126
# 126: loss=0.707, reward_mean=-7.1, reward_bound=-6.5
# Iter: 127
# 127: loss=0.911, reward_mean=-7.1, reward_bound=-6.8
# Iter: 128
# 128: loss=0.813, reward_mean=-7.3, reward_bound=-6.9
# Iter: 129
# 129: loss=0.762, reward_mean=-7.1, reward_bound=-6.7
# Iter: 130
# 130: loss=0.710, reward_mean=-7.0, reward_bound=-6.6
# Iter: 131
# 131: loss=0.730, reward_mean=-7.2, reward_bound=-7.0
# Iter: 132
# 132: loss=0.724, reward_mean=-6.8, reward_bound=-6.4
# Iter: 133
# 133: loss=0.872, reward_mean=-7.4, reward_bound=-7.1
# Iter: 134
# 134: loss=0.626, reward_mean=-7.1, reward_bound=-6.8
# Iter: 135
# 135: loss=0.803, reward_mean=-7.0, reward_bound=-6.7
# Iter: 136
# 136: loss=0.687, reward_mean=-7.3, reward_bound=-7.0
# Iter: 137
# 137: loss=0.667, reward_mean=-7.2, reward_bound=-6.9
# Iter: 138
# 138: loss=0.610, reward_mean=-7.1, reward_bound=-6.7
# Iter: 139
# 139: loss=0.633, reward_mean=-6.9, reward_bound=-6.6
# Iter: 140
# 140: loss=0.549, reward_mean=-7.1, reward_bound=-6.9
# Iter: 141
# 141: loss=0.375, reward_mean=-6.9, reward_bound=-6.6
# Iter: 142
# 142: loss=0.712, reward_mean=-6.9, reward_bound=-6.7
# Iter: 143
# 143: loss=0.530, reward_mean=-6.9, reward_bound=-6.3
# Iter: 144
# 144: loss=0.496, reward_mean=-7.1, reward_bound=-6.7
# Iter: 145
# 145: loss=0.571, reward_mean=-7.2, reward_bound=-6.6
# Iter: 146
# 146: loss=0.500, reward_mean=-6.9, reward_bound=-6.7
# Iter: 147
# 147: loss=0.446, reward_mean=-7.3, reward_bound=-6.7
# Iter: 148
# 148: loss=0.461, reward_mean=-7.4, reward_bound=-7.0
# Iter: 149
# 149: loss=0.416, reward_mean=-7.2, reward_bound=-6.7
# Iter: 150
# 150: loss=0.457, reward_mean=-7.5, reward_bound=-7.0
# Iter: 151
# 151: loss=0.724, reward_mean=-7.2, reward_bound=-6.5
# Iter: 152
# 152: loss=0.631, reward_mean=-7.8, reward_bound=-7.1
# Iter: 153
# 153: loss=0.430, reward_mean=-7.4, reward_bound=-7.1
# Iter: 154
# 154: loss=0.601, reward_mean=-7.3, reward_bound=-7.0
# Iter: 155
# 155: loss=0.420, reward_mean=-7.2, reward_bound=-6.7
# Iter: 156
# 156: loss=0.585, reward_mean=-7.4, reward_bound=-6.9
# Iter: 157
# 157: loss=0.378, reward_mean=-6.9, reward_bound=-6.4
# Iter: 158
# 158: loss=0.640, reward_mean=-7.2, reward_bound=-6.7
# Iter: 159
# 159: loss=0.733, reward_mean=-7.4, reward_bound=-7.0
# Iter: 160
# 160: loss=0.439, reward_mean=-7.1, reward_bound=-6.4
# Iter: 161
# 161: loss=0.591, reward_mean=-7.2, reward_bound=-6.7
# Iter: 162
# 162: loss=0.438, reward_mean=-7.1, reward_bound=-6.7
# Iter: 163
# 163: loss=0.389, reward_mean=-7.3, reward_bound=-7.0
# Iter: 164
# 164: loss=0.407, reward_mean=-7.2, reward_bound=-6.6
# Iter: 165
# 165: loss=0.478, reward_mean=-7.2, reward_bound=-6.9
# Iter: 166
# 166: loss=0.433, reward_mean=-7.3, reward_bound=-7.0
# Iter: 167
# 167: loss=0.479, reward_mean=-6.9, reward_bound=-6.5
# Iter: 168
# 168: loss=0.449, reward_mean=-6.8, reward_bound=-6.4
# Iter: 169
# 169: loss=0.452, reward_mean=-7.2, reward_bound=-6.8
# Iter: 170
# 170: loss=0.412, reward_mean=-7.0, reward_bound=-6.5
# Iter: 171
# 171: loss=0.296, reward_mean=-7.2, reward_bound=-6.6
# Iter: 172
# 172: loss=0.251, reward_mean=-7.0, reward_bound=-6.6
# Iter: 173
# 173: loss=0.426, reward_mean=-7.3, reward_bound=-6.9
# Iter: 174
# 174: loss=0.286, reward_mean=-6.9, reward_bound=-6.5
# Iter: 175
# 175: loss=0.285, reward_mean=-7.3, reward_bound=-6.7
# Iter: 176
# 176: loss=0.499, reward_mean=-7.1, reward_bound=-6.6
# Iter: 177
# 177: loss=0.346, reward_mean=-7.1, reward_bound=-6.6
# Iter: 178
# 178: loss=0.297, reward_mean=-6.9, reward_bound=-6.6
# Iter: 179
# 179: loss=0.317, reward_mean=-7.1, reward_bound=-6.5
# Iter: 180
# 180: loss=0.374, reward_mean=-6.9, reward_bound=-6.5
# Iter: 181
# 181: loss=0.362, reward_mean=-7.0, reward_bound=-6.4
# Iter: 182
# 182: loss=0.408, reward_mean=-6.7, reward_bound=-6.5
# Iter: 183
# 183: loss=0.430, reward_mean=-6.8, reward_bound=-6.6
# Iter: 184
# 184: loss=0.259, reward_mean=-7.0, reward_bound=-6.7
# Iter: 185
# 185: loss=0.312, reward_mean=-6.8, reward_bound=-6.4
# Iter: 186
# 186: loss=0.407, reward_mean=-7.1, reward_bound=-7.0
# Iter: 187
# 187: loss=0.331, reward_mean=-7.3, reward_bound=-6.7
# Iter: 188
# 188: loss=0.358, reward_mean=-7.0, reward_bound=-6.7
# Iter: 189
# 189: loss=0.473, reward_mean=-7.1, reward_bound=-6.9
# Iter: 190
# 190: loss=0.313, reward_mean=-7.2, reward_bound=-6.8
# Iter: 191
# 191: loss=0.447, reward_mean=-7.0, reward_bound=-6.7
# Iter: 192
# 192: loss=0.304, reward_mean=-7.1, reward_bound=-6.9
# Iter: 193
# 193: loss=0.363, reward_mean=-7.2, reward_bound=-6.9
# Iter: 194
# 194: loss=0.311, reward_mean=-6.9, reward_bound=-6.6
# Iter: 195
# 195: loss=0.386, reward_mean=-6.8, reward_bound=-6.5
# Iter: 196
# 196: loss=0.343, reward_mean=-6.8, reward_bound=-6.4
# Iter: 197
# 197: loss=0.303, reward_mean=-6.7, reward_bound=-6.4
# Iter: 198
# 198: loss=0.333, reward_mean=-7.0, reward_bound=-6.5
# Iter: 199
# 199: loss=0.373, reward_mean=-6.8, reward_bound=-6.5
# Iter: 200
# 200: loss=0.348, reward_mean=-7.1, reward_bound=-6.6
# Iter: 201
# 201: loss=0.343, reward_mean=-7.1, reward_bound=-6.4
# Iter: 202
# 202: loss=0.313, reward_mean=-7.0, reward_bound=-6.7
# Iter: 203
# 203: loss=0.291, reward_mean=-6.9, reward_bound=-6.6
# Iter: 204
# 204: loss=0.362, reward_mean=-6.7, reward_bound=-6.4
# Iter: 205
# 205: loss=0.352, reward_mean=-7.1, reward_bound=-6.6
# Iter: 206
# 206: loss=0.405, reward_mean=-6.9, reward_bound=-6.4
# Iter: 207
# 207: loss=0.358, reward_mean=-6.8, reward_bound=-6.5
# Iter: 208
# 208: loss=0.267, reward_mean=-7.2, reward_bound=-6.7
# Iter: 209
# 209: loss=0.496, reward_mean=-7.1, reward_bound=-6.5
# Iter: 210
# 210: loss=0.304, reward_mean=-7.1, reward_bound=-6.6
# Iter: 211
# 211: loss=0.250, reward_mean=-7.2, reward_bound=-6.8
# Iter: 212
# 212: loss=0.213, reward_mean=-6.8, reward_bound=-6.4
# Iter: 213
# 213: loss=0.292, reward_mean=-6.9, reward_bound=-6.7
# Iter: 214
# 214: loss=0.352, reward_mean=-7.0, reward_bound=-6.5
# Iter: 215
# 215: loss=0.255, reward_mean=-6.8, reward_bound=-6.5
# Iter: 216
# 216: loss=0.253, reward_mean=-7.0, reward_bound=-6.5
# Iter: 217
# 217: loss=0.277, reward_mean=-7.0, reward_bound=-6.7
# Iter: 218
# 218: loss=0.396, reward_mean=-6.8, reward_bound=-6.3
# Iter: 219
# 219: loss=0.233, reward_mean=-6.9, reward_bound=-6.6
# Iter: 220
# 220: loss=0.253, reward_mean=-6.9, reward_bound=-6.4
# Iter: 221
# 221: loss=0.375, reward_mean=-7.0, reward_bound=-6.6
# Iter: 222
# 222: loss=0.274, reward_mean=-6.9, reward_bound=-6.5
# Iter: 223
# 223: loss=0.458, reward_mean=-7.4, reward_bound=-7.0
# Iter: 224
# 224: loss=0.369, reward_mean=-7.0, reward_bound=-6.4
# Iter: 225
# 225: loss=0.348, reward_mean=-7.1, reward_bound=-6.7
# Iter: 226
# 226: loss=0.276, reward_mean=-7.1, reward_bound=-6.7
# Iter: 227
# 227: loss=0.279, reward_mean=-6.7, reward_bound=-6.4
# Iter: 228
# 228: loss=0.265, reward_mean=-6.8, reward_bound=-6.4
# Iter: 229
# 229: loss=0.362, reward_mean=-6.9, reward_bound=-6.6
# Iter: 230
# 230: loss=0.414, reward_mean=-6.9, reward_bound=-6.4
# Iter: 231
# 231: loss=0.334, reward_mean=-6.8, reward_bound=-6.7
# Iter: 232
# 232: loss=0.319, reward_mean=-6.8, reward_bound=-6.4
# Iter: 233
# 233: loss=0.253, reward_mean=-6.7, reward_bound=-6.4
# Iter: 234
# 234: loss=0.216, reward_mean=-6.8, reward_bound=-6.5
# Iter: 235
# 235: loss=0.320, reward_mean=-6.7, reward_bound=-6.5
# Iter: 236
# 236: loss=0.311, reward_mean=-6.9, reward_bound=-6.6
# Iter: 237
# 237: loss=0.361, reward_mean=-7.0, reward_bound=-6.5
# Iter: 238
# 238: loss=0.362, reward_mean=-7.0, reward_bound=-6.7
# Iter: 239
# 239: loss=0.248, reward_mean=-6.5, reward_bound=-6.3
# Iter: 240
# 240: loss=0.304, reward_mean=-6.9, reward_bound=-6.5
# Iter: 241
# 241: loss=0.284, reward_mean=-7.2, reward_bound=-6.6
# Iter: 242
# 242: loss=0.252, reward_mean=-7.0, reward_bound=-6.7
# Iter: 243
# 243: loss=0.226, reward_mean=-7.0, reward_bound=-6.7
# Iter: 244
# 244: loss=0.379, reward_mean=-7.0, reward_bound=-6.6
# Iter: 245
# 245: loss=0.369, reward_mean=-6.9, reward_bound=-6.4
# Iter: 246
# 246: loss=0.230, reward_mean=-6.9, reward_bound=-6.8
# Iter: 247
# 247: loss=0.262, reward_mean=-6.9, reward_bound=-6.4
# Iter: 248
# 248: loss=0.191, reward_mean=-7.0, reward_bound=-6.6
# Iter: 249
# 249: loss=0.234, reward_mean=-7.0, reward_bound=-6.8
# Iter: 250
# 250: loss=0.309, reward_mean=-6.9, reward_bound=-6.5
# Iter: 251
# 251: loss=0.400, reward_mean=-7.1, reward_bound=-6.6
# Iter: 252
# 252: loss=0.221, reward_mean=-6.8, reward_bound=-6.5
# Iter: 253
# 253: loss=0.229, reward_mean=-7.3, reward_bound=-6.5
# Iter: 254
# 254: loss=0.267, reward_mean=-7.2, reward_bound=-6.5
# Iter: 255
# 255: loss=0.186, reward_mean=-7.3, reward_bound=-6.8
# Iter: 256
# 256: loss=0.160, reward_mean=-7.3, reward_bound=-6.7
# Iter: 257
# 257: loss=0.297, reward_mean=-7.2, reward_bound=-6.8
# Iter: 258
# 258: loss=0.310, reward_mean=-7.1, reward_bound=-6.5
# Iter: 259
# 259: loss=0.234, reward_mean=-6.9, reward_bound=-6.7
# Iter: 260
# 260: loss=0.222, reward_mean=-6.8, reward_bound=-6.5
# Iter: 261
# 261: loss=0.352, reward_mean=-6.8, reward_bound=-6.5
# Iter: 262
# 262: loss=0.253, reward_mean=-7.0, reward_bound=-6.7
# Iter: 263
# 263: loss=0.423, reward_mean=-6.8, reward_bound=-6.4
# Iter: 264
# 264: loss=0.225, reward_mean=-6.8, reward_bound=-6.5
# Iter: 265
# 265: loss=0.305, reward_mean=-7.1, reward_bound=-6.8
# Iter: 266
# 266: loss=0.276, reward_mean=-7.1, reward_bound=-7.0
# Iter: 267
# 267: loss=0.358, reward_mean=-6.7, reward_bound=-6.4
# Iter: 268
# 268: loss=0.312, reward_mean=-7.0, reward_bound=-6.8
# Iter: 269
# 269: loss=0.247, reward_mean=-6.8, reward_bound=-6.4
# Iter: 270
# 270: loss=0.167, reward_mean=-6.8, reward_bound=-6.5
# Iter: 271
# 271: loss=0.246, reward_mean=-6.9, reward_bound=-6.6
# Iter: 272
# 272: loss=0.204, reward_mean=-7.0, reward_bound=-6.5
# Iter: 273
# 273: loss=0.323, reward_mean=-6.9, reward_bound=-6.6
# Iter: 274
# 274: loss=0.218, reward_mean=-7.2, reward_bound=-7.1
# Iter: 275
# 275: loss=0.231, reward_mean=-7.0, reward_bound=-6.6
# Iter: 276
# 276: loss=0.236, reward_mean=-7.0, reward_bound=-6.4
# Iter: 277
# 277: loss=0.307, reward_mean=-7.1, reward_bound=-6.6
# Iter: 278
# 278: loss=0.264, reward_mean=-6.9, reward_bound=-6.4
# Iter: 279
# 279: loss=0.236, reward_mean=-7.3, reward_bound=-6.6
# Iter: 280
# 280: loss=0.257, reward_mean=-6.9, reward_bound=-6.5
# Iter: 281
# 281: loss=0.283, reward_mean=-7.1, reward_bound=-6.8
# Iter: 282
# 282: loss=0.295, reward_mean=-7.0, reward_bound=-6.6
# Iter: 283
# 283: loss=0.363, reward_mean=-7.1, reward_bound=-6.8
# Iter: 284
# 284: loss=0.242, reward_mean=-6.9, reward_bound=-6.7
# Iter: 285
# 285: loss=0.312, reward_mean=-6.9, reward_bound=-6.5
# Iter: 286
# 286: loss=0.208, reward_mean=-7.0, reward_bound=-6.5
# Iter: 287
# 287: loss=0.247, reward_mean=-7.4, reward_bound=-7.0
# Iter: 288
# 288: loss=0.199, reward_mean=-6.9, reward_bound=-6.5
# Iter: 289
# 289: loss=0.201, reward_mean=-7.0, reward_bound=-6.7
# Iter: 290
# 290: loss=0.386, reward_mean=-7.2, reward_bound=-7.0
# Iter: 291
# 291: loss=0.210, reward_mean=-7.4, reward_bound=-7.0
# Iter: 292
# 292: loss=0.262, reward_mean=-7.0, reward_bound=-6.5
# Iter: 293
# 293: loss=0.229, reward_mean=-7.1, reward_bound=-6.4
# Iter: 294
# 294: loss=0.258, reward_mean=-7.2, reward_bound=-6.8
# Iter: 295
# 295: loss=0.363, reward_mean=-7.0, reward_bound=-6.6
# Iter: 296
# 296: loss=0.381, reward_mean=-6.9, reward_bound=-6.7
# Iter: 297
# 297: loss=0.268, reward_mean=-6.8, reward_bound=-6.4
# Iter: 298
# 298: loss=0.248, reward_mean=-7.0, reward_bound=-6.7
# Iter: 299
# 299: loss=0.287, reward_mean=-7.0, reward_bound=-6.5
# Iter: 300
# 300: loss=0.214, reward_mean=-6.9, reward_bound=-6.6
# Iter: 301
# 301: loss=0.288, reward_mean=-7.1, reward_bound=-6.7
# Iter: 302
# 302: loss=0.268, reward_mean=-6.9, reward_bound=-6.7
# Iter: 303
# 303: loss=0.306, reward_mean=-6.9, reward_bound=-6.5
# Iter: 304
# 304: loss=0.229, reward_mean=-6.6, reward_bound=-6.4
# Iter: 305
# 305: loss=0.224, reward_mean=-7.0, reward_bound=-6.5
# Iter: 306
# 306: loss=0.283, reward_mean=-6.8, reward_bound=-6.5
# Iter: 307
# 307: loss=0.199, reward_mean=-6.8, reward_bound=-6.4
# Iter: 308
# 308: loss=0.173, reward_mean=-6.9, reward_bound=-6.4
# Iter: 309
# 309: loss=0.203, reward_mean=-6.8, reward_bound=-6.6
# Iter: 310
# 310: loss=0.259, reward_mean=-7.1, reward_bound=-6.7
# Iter: 311
# 311: loss=0.261, reward_mean=-6.6, reward_bound=-6.4
# Iter: 312
# 312: loss=0.230, reward_mean=-6.8, reward_bound=-6.5
# Iter: 313
# 313: loss=0.228, reward_mean=-7.2, reward_bound=-6.7
# Iter: 314
# 314: loss=0.244, reward_mean=-7.6, reward_bound=-7.1
# Iter: 315
# 315: loss=0.154, reward_mean=-7.6, reward_bound=-7.3
# Iter: 316
# 316: loss=0.149, reward_mean=-7.5, reward_bound=-6.6
# Iter: 317
# 317: loss=0.144, reward_mean=-7.2, reward_bound=-6.5
# Iter: 318
# 318: loss=0.161, reward_mean=-7.3, reward_bound=-6.8
# Iter: 319
# 319: loss=0.284, reward_mean=-7.0, reward_bound=-6.5
# Iter: 320
# 320: loss=0.127, reward_mean=-7.3, reward_bound=-6.8
# Iter: 321
# 321: loss=0.159, reward_mean=-7.3, reward_bound=-6.4
# Iter: 322
# 322: loss=0.165, reward_mean=-7.3, reward_bound=-6.8
# Iter: 323
# 323: loss=0.200, reward_mean=-6.9, reward_bound=-6.6
# Iter: 324
# 324: loss=0.260, reward_mean=-6.9, reward_bound=-6.6
# Iter: 325
# 325: loss=0.247, reward_mean=-7.0, reward_bound=-6.6
# Iter: 326
# 326: loss=0.182, reward_mean=-6.9, reward_bound=-6.7
# Iter: 327
# 327: loss=0.259, reward_mean=-6.9, reward_bound=-6.4
# Iter: 328
# 328: loss=0.247, reward_mean=-6.9, reward_bound=-6.6
# Iter: 329
# 329: loss=0.331, reward_mean=-6.9, reward_bound=-6.5
# Iter: 330
# 330: loss=0.172, reward_mean=-6.9, reward_bound=-6.6
# Iter: 331
# 331: loss=0.252, reward_mean=-7.0, reward_bound=-6.7
# Iter: 332
# 332: loss=0.305, reward_mean=-6.9, reward_bound=-6.5
# Iter: 333
# 333: loss=0.277, reward_mean=-7.1, reward_bound=-6.6
# Iter: 334
# 334: loss=0.245, reward_mean=-6.7, reward_bound=-6.4
# Iter: 335
# 335: loss=0.240, reward_mean=-6.6, reward_bound=-6.4
# Iter: 336
# 336: loss=0.205, reward_mean=-6.7, reward_bound=-6.4
# Iter: 337
# 337: loss=0.236, reward_mean=-6.9, reward_bound=-6.6
# Iter: 338
# 338: loss=0.369, reward_mean=-6.9, reward_bound=-6.6
# Iter: 339
# 339: loss=0.304, reward_mean=-7.1, reward_bound=-6.8
# Iter: 340
# 340: loss=0.214, reward_mean=-6.9, reward_bound=-6.5
# Iter: 341
# 341: loss=0.359, reward_mean=-7.0, reward_bound=-6.7
# Iter: 342
# 342: loss=0.239, reward_mean=-6.7, reward_bound=-6.3
# Iter: 343
# 343: loss=0.260, reward_mean=-7.0, reward_bound=-6.6
# Iter: 344
# 344: loss=0.254, reward_mean=-6.7, reward_bound=-6.3
# Iter: 345
# 345: loss=0.199, reward_mean=-7.0, reward_bound=-6.5
# Iter: 346
# 346: loss=0.248, reward_mean=-7.3, reward_bound=-6.8
# Iter: 347
# 347: loss=0.260, reward_mean=-7.2, reward_bound=-6.7
# Iter: 348
# 348: loss=0.216, reward_mean=-6.8, reward_bound=-6.6
# Iter: 349
# 349: loss=0.265, reward_mean=-6.7, reward_bound=-6.4
# Iter: 350
# 350: loss=0.273, reward_mean=-6.9, reward_bound=-6.5
# Iter: 351
# 351: loss=0.332, reward_mean=-6.8, reward_bound=-6.4
# Iter: 352
# 352: loss=0.236, reward_mean=-7.1, reward_bound=-6.6
# Iter: 353
# 353: loss=0.215, reward_mean=-7.1, reward_bound=-6.6
# Iter: 354
# 354: loss=0.392, reward_mean=-6.8, reward_bound=-6.7
# Iter: 355
# 355: loss=0.278, reward_mean=-7.1, reward_bound=-6.7
# Iter: 356
# 356: loss=0.248, reward_mean=-6.8, reward_bound=-6.5
# Iter: 357
# 357: loss=0.285, reward_mean=-6.9, reward_bound=-6.5
# Iter: 358
# 358: loss=0.334, reward_mean=-7.0, reward_bound=-6.7
# Iter: 359
# 359: loss=0.217, reward_mean=-6.7, reward_bound=-6.3
# Iter: 360
# 360: loss=0.247, reward_mean=-6.8, reward_bound=-6.4
# Iter: 361
# 361: loss=0.186, reward_mean=-6.9, reward_bound=-6.4
# Iter: 362
# 362: loss=0.326, reward_mean=-7.1, reward_bound=-6.6
# Iter: 363
# 363: loss=0.115, reward_mean=-7.3, reward_bound=-6.6
# Iter: 364
# 364: loss=0.184, reward_mean=-7.6, reward_bound=-6.8
# Iter: 365
# 365: loss=0.198, reward_mean=-7.9, reward_bound=-7.5
# Iter: 366
# 366: loss=0.217, reward_mean=-7.7, reward_bound=-7.0
# Iter: 367
# 367: loss=0.210, reward_mean=-7.9, reward_bound=-7.9
# Iter: 368
# 368: loss=0.186, reward_mean=-7.5, reward_bound=-6.8
# Iter: 369
# 369: loss=0.182, reward_mean=-7.2, reward_bound=-6.6
# Iter: 370
# 370: loss=0.212, reward_mean=-7.6, reward_bound=-7.1
# Iter: 371
# 371: loss=0.229, reward_mean=-7.3, reward_bound=-6.9
# Iter: 372
# 372: loss=0.184, reward_mean=-7.1, reward_bound=-6.5
# Iter: 373
# 373: loss=0.166, reward_mean=-6.8, reward_bound=-6.4
# Iter: 374
# 374: loss=0.172, reward_mean=-6.9, reward_bound=-6.6
# Iter: 375
# 375: loss=0.238, reward_mean=-6.8, reward_bound=-6.4
# Iter: 376
# 376: loss=0.256, reward_mean=-6.9, reward_bound=-6.6
# Iter: 377
# 377: loss=0.377, reward_mean=-6.9, reward_bound=-6.7
# Iter: 378
# 378: loss=0.222, reward_mean=-5.3, reward_bound=-6.2
# Iter: 379
# 379: loss=0.163, reward_mean=-6.7, reward_bound=-6.6
# Iter: 380
# 380: loss=0.238, reward_mean=-6.7, reward_bound=-6.5
# Iter: 381
# 381: loss=0.177, reward_mean=-7.0, reward_bound=-6.6
# Iter: 382
# 382: loss=0.284, reward_mean=-6.8, reward_bound=-6.4
# Iter: 383
# 383: loss=0.199, reward_mean=-7.1, reward_bound=-6.8
# Iter: 384
# 384: loss=0.236, reward_mean=-6.9, reward_bound=-6.6
# Iter: 385
# 385: loss=0.145, reward_mean=-6.9, reward_bound=-6.4
# Iter: 386
# 386: loss=0.282, reward_mean=-6.7, reward_bound=-6.6
# Iter: 387
# 387: loss=0.150, reward_mean=-6.9, reward_bound=-6.6
# Iter: 388
# 388: loss=0.212, reward_mean=-6.8, reward_bound=-6.4
# Iter: 389
# 389: loss=0.221, reward_mean=-6.8, reward_bound=-6.5
# Iter: 390
# 390: loss=0.209, reward_mean=-6.9, reward_bound=-6.5
# Iter: 391
# 391: loss=0.187, reward_mean=-7.2, reward_bound=-6.7
# Iter: 392
# 392: loss=0.289, reward_mean=-7.0, reward_bound=-6.6
# Iter: 393
# 393: loss=0.230, reward_mean=-7.0, reward_bound=-6.5
# Iter: 394
# 394: loss=0.192, reward_mean=-7.4, reward_bound=-7.0
# Iter: 395
# 395: loss=0.190, reward_mean=-6.8, reward_bound=-6.5
# Iter: 396
# 396: loss=0.187, reward_mean=-6.8, reward_bound=-6.4
# Iter: 397
# 397: loss=0.279, reward_mean=-6.9, reward_bound=-6.7
# Iter: 398
# 398: loss=0.285, reward_mean=-6.9, reward_bound=-6.7
# Iter: 399
# 399: loss=0.286, reward_mean=-6.8, reward_bound=-6.5
# Iter: 400
# 400: loss=0.257, reward_mean=-6.9, reward_bound=-6.6
# Iter: 401
# 401: loss=0.217, reward_mean=-7.3, reward_bound=-6.9
# Iter: 402
# 402: loss=0.300, reward_mean=-6.9, reward_bound=-6.6
# Iter: 403
# 403: loss=0.284, reward_mean=-6.9, reward_bound=-6.7
# Iter: 404
# 404: loss=0.278, reward_mean=-7.1, reward_bound=-6.9
# Iter: 405
# 405: loss=0.222, reward_mean=-6.7, reward_bound=-6.4
# Iter: 406
# 406: loss=0.305, reward_mean=-6.9, reward_bound=-6.6
# Iter: 407
# 407: loss=0.275, reward_mean=-6.8, reward_bound=-6.5
# Iter: 408
# 408: loss=0.178, reward_mean=-7.0, reward_bound=-6.5
# Iter: 409
# 409: loss=0.196, reward_mean=-6.9, reward_bound=-6.4
# Iter: 410
# 410: loss=0.132, reward_mean=-6.9, reward_bound=-6.5
# Iter: 411
# 411: loss=0.243, reward_mean=-7.1, reward_bound=-6.6
# Iter: 412
# 412: loss=0.182, reward_mean=-7.3, reward_bound=-6.6
# Iter: 413
# 413: loss=0.160, reward_mean=-7.2, reward_bound=-6.5
# Iter: 414
# 414: loss=0.252, reward_mean=-7.3, reward_bound=-6.9
# Iter: 415
# 415: loss=0.119, reward_mean=-6.9, reward_bound=-6.5
# Iter: 416
# 416: loss=0.146, reward_mean=-7.0, reward_bound=-6.6
# Iter: 417
# 417: loss=0.167, reward_mean=-7.0, reward_bound=-6.5
# Iter: 418
# 418: loss=0.214, reward_mean=-6.6, reward_bound=-6.4
# Iter: 419
# 419: loss=0.388, reward_mean=-7.0, reward_bound=-6.6
# Iter: 420
# 420: loss=0.198, reward_mean=-6.6, reward_bound=-6.4
# Iter: 421
# 421: loss=0.298, reward_mean=-6.8, reward_bound=-6.4
# Iter: 422
# 422: loss=0.327, reward_mean=-7.0, reward_bound=-6.7
# Iter: 423
# 423: loss=0.235, reward_mean=-7.2, reward_bound=-6.7
# Iter: 424
# 424: loss=0.271, reward_mean=-7.1, reward_bound=-7.0
# Iter: 425
# 425: loss=0.447, reward_mean=-7.3, reward_bound=-6.7
# Iter: 426
# 426: loss=0.348, reward_mean=-7.8, reward_bound=-7.1
# Iter: 427
# 427: loss=0.337, reward_mean=-7.5, reward_bound=-6.9
# Iter: 428
# 428: loss=0.305, reward_mean=-7.7, reward_bound=-6.9
# Iter: 429
# 429: loss=0.362, reward_mean=-7.7, reward_bound=-7.1
# Iter: 430
# 430: loss=0.387, reward_mean=-7.3, reward_bound=-7.0
# Iter: 431
# 431: loss=0.260, reward_mean=-7.2, reward_bound=-7.0
# Iter: 432
# 432: loss=0.352, reward_mean=-7.0, reward_bound=-6.7
# Iter: 433
# 433: loss=0.247, reward_mean=-6.7, reward_bound=-6.4
# Iter: 434
# 434: loss=0.231, reward_mean=-6.9, reward_bound=-6.6
# Iter: 435
# 435: loss=0.167, reward_mean=-6.7, reward_bound=-6.5
# Iter: 436
# 436: loss=0.195, reward_mean=-6.9, reward_bound=-6.6
# Iter: 437
# 437: loss=0.193, reward_mean=-6.8, reward_bound=-6.5
# Iter: 438
# 438: loss=0.186, reward_mean=-7.2, reward_bound=-6.5
# Iter: 439
# 439: loss=0.252, reward_mean=-7.7, reward_bound=-7.1
# Iter: 440
# 440: loss=0.144, reward_mean=-7.6, reward_bound=-6.9
# Iter: 441
# 441: loss=0.178, reward_mean=-7.7, reward_bound=-7.0
# Iter: 442
# 442: loss=0.255, reward_mean=-7.5, reward_bound=-7.0
# Iter: 443
# 443: loss=0.261, reward_mean=-7.6, reward_bound=-7.1
# Iter: 444
# 444: loss=0.209, reward_mean=-7.5, reward_bound=-6.7
# Iter: 445
# 445: loss=0.224, reward_mean=-6.9, reward_bound=-6.3
# Iter: 446
# 446: loss=0.261, reward_mean=-7.0, reward_bound=-6.6
# Iter: 447
# 447: loss=0.266, reward_mean=-7.0, reward_bound=-6.5
# Iter: 448
# 448: loss=0.370, reward_mean=-6.8, reward_bound=-6.5
# Iter: 449
# 449: loss=0.351, reward_mean=-6.7, reward_bound=-6.4
# Iter: 450
# 450: loss=0.287, reward_mean=-7.2, reward_bound=-7.0
# Iter: 451
# 451: loss=0.287, reward_mean=-7.0, reward_bound=-6.5
# Iter: 452
# 452: loss=0.440, reward_mean=-6.7, reward_bound=-6.4
# Iter: 453
# 453: loss=0.298, reward_mean=-7.1, reward_bound=-6.6
# Iter: 454
# 454: loss=0.501, reward_mean=-7.1, reward_bound=-6.9
# Iter: 455
# 455: loss=0.401, reward_mean=-7.0, reward_bound=-6.8
# Iter: 456
# 456: loss=0.473, reward_mean=-7.1, reward_bound=-6.7
# Iter: 457
# 457: loss=0.376, reward_mean=-7.2, reward_bound=-6.8
# Iter: 458
# 458: loss=0.446, reward_mean=-7.1, reward_bound=-6.7
# Iter: 459
# 459: loss=0.406, reward_mean=-7.2, reward_bound=-6.7
# Iter: 460
# 460: loss=0.452, reward_mean=-7.2, reward_bound=-6.8
# Iter: 461
# 461: loss=0.488, reward_mean=-7.3, reward_bound=-6.9
# Iter: 462
# 462: loss=0.384, reward_mean=-7.2, reward_bound=-6.8
# Iter: 463
# 463: loss=0.418, reward_mean=-7.2, reward_bound=-6.9
# Iter: 464
# 464: loss=0.445, reward_mean=-7.1, reward_bound=-6.5
# Iter: 465
# 465: loss=0.355, reward_mean=-7.1, reward_bound=-6.9
# Iter: 466
# 466: loss=0.383, reward_mean=-7.0, reward_bound=-6.7
# Iter: 467
# 467: loss=0.334, reward_mean=-6.8, reward_bound=-6.5
# Iter: 468
# 468: loss=0.326, reward_mean=-6.8, reward_bound=-6.4
# Iter: 469
# 469: loss=0.448, reward_mean=-7.0, reward_bound=-6.8
# Iter: 470
# 470: loss=0.357, reward_mean=-6.9, reward_bound=-6.6
# Iter: 471
# 471: loss=0.144, reward_mean=-5.4, reward_bound=-6.2
# Iter: 472
# 472: loss=0.387, reward_mean=-7.1, reward_bound=-6.5
# Iter: 473
# 473: loss=0.282, reward_mean=-6.7, reward_bound=-6.2
# Iter: 474
# 474: loss=0.241, reward_mean=-7.0, reward_bound=-6.6
# Iter: 475
# 475: loss=0.290, reward_mean=-7.5, reward_bound=-7.0
# Iter: 476
# 476: loss=0.234, reward_mean=-7.0, reward_bound=-6.8
# Iter: 477
# 477: loss=0.209, reward_mean=-7.0, reward_bound=-6.5
# Iter: 478
# 478: loss=0.220, reward_mean=-7.1, reward_bound=-6.7
# Iter: 479
# 479: loss=0.185, reward_mean=-7.1, reward_bound=-6.6
# Iter: 480
# 480: loss=0.222, reward_mean=-7.0, reward_bound=-6.6
# Iter: 481
# 481: loss=0.162, reward_mean=-7.2, reward_bound=-6.8
# Iter: 482
# 482: loss=0.195, reward_mean=-7.3, reward_bound=-6.8
# Iter: 483
# 483: loss=0.192, reward_mean=-7.2, reward_bound=-6.6
# Iter: 484
# 484: loss=0.193, reward_mean=-6.8, reward_bound=-6.4
# Iter: 485
# 485: loss=0.236, reward_mean=-6.8, reward_bound=-6.6
# Iter: 486
# 486: loss=0.177, reward_mean=-7.0, reward_bound=-6.5
# Iter: 487
# 487: loss=0.208, reward_mean=-6.8, reward_bound=-6.6
# Iter: 488
# 488: loss=0.190, reward_mean=-6.8, reward_bound=-6.6
# Iter: 489
# 489: loss=0.245, reward_mean=-7.0, reward_bound=-6.5
# Iter: 490
# 490: loss=0.228, reward_mean=-6.8, reward_bound=-6.5
# Iter: 491
# 491: loss=0.173, reward_mean=-6.9, reward_bound=-6.6
# Iter: 492
# 492: loss=0.239, reward_mean=-7.2, reward_bound=-6.9
# Iter: 493
# 493: loss=0.269, reward_mean=-7.0, reward_bound=-6.6
# Iter: 494
# 494: loss=0.376, reward_mean=-7.1, reward_bound=-6.8
# Iter: 495
# 495: loss=0.186, reward_mean=-7.0, reward_bound=-6.8
# Iter: 496
# 496: loss=0.289, reward_mean=-6.7, reward_bound=-6.4
# Iter: 497
# 497: loss=0.180, reward_mean=-6.9, reward_bound=-6.8
# Iter: 498
# 498: loss=0.184, reward_mean=-6.8, reward_bound=-6.6
# Iter: 499
# 499: loss=0.299, reward_mean=-6.9, reward_bound=-6.6
# Iter: 500
# 500: loss=0.204, reward_mean=-6.7, reward_bound=-6.5
# Iter: 501
# 501: loss=0.223, reward_mean=-6.9, reward_bound=-6.4
# Iter: 502
# 502: loss=0.229, reward_mean=-6.9, reward_bound=-6.7
# Iter: 503
# 503: loss=0.136, reward_mean=-7.3, reward_bound=-6.8
# Iter: 504
# 504: loss=0.156, reward_mean=-7.2, reward_bound=-6.5
# Iter: 505
# 505: loss=0.134, reward_mean=-7.3, reward_bound=-6.7
# Iter: 506
# 506: loss=0.104, reward_mean=-7.3, reward_bound=-6.8
# Iter: 507
# 507: loss=0.131, reward_mean=-7.4, reward_bound=-6.9
# Iter: 508
# 508: loss=0.157, reward_mean=-7.2, reward_bound=-6.5
# Iter: 509
# 509: loss=0.185, reward_mean=-6.8, reward_bound=-6.5
# Iter: 510
# 510: loss=0.143, reward_mean=-7.1, reward_bound=-6.4
# Iter: 511
# 511: loss=0.205, reward_mean=-6.9, reward_bound=-6.4
# Iter: 512
# 512: loss=0.202, reward_mean=-7.0, reward_bound=-6.7
# Iter: 513
# 513: loss=0.207, reward_mean=-6.9, reward_bound=-6.5
# Iter: 514
# 514: loss=0.227, reward_mean=-6.8, reward_bound=-6.3
# Iter: 515
# 515: loss=0.289, reward_mean=-6.8, reward_bound=-6.5
# Iter: 516
# 516: loss=0.302, reward_mean=-6.9, reward_bound=-6.6
# Iter: 517
# 517: loss=0.267, reward_mean=-6.9, reward_bound=-6.7
# Iter: 518
# 518: loss=0.282, reward_mean=-6.8, reward_bound=-6.5
# Iter: 519
# 519: loss=0.235, reward_mean=-7.0, reward_bound=-6.5
# Iter: 520
# 520: loss=0.251, reward_mean=-6.8, reward_bound=-6.5
# Iter: 521
# 521: loss=0.209, reward_mean=-6.7, reward_bound=-6.4
# Iter: 522
# 522: loss=0.248, reward_mean=-7.0, reward_bound=-6.7
# Iter: 523
# 523: loss=0.174, reward_mean=-7.0, reward_bound=-6.7
# Iter: 524
# 524: loss=0.276, reward_mean=-6.8, reward_bound=-6.5
# Iter: 525
# 525: loss=0.248, reward_mean=-6.9, reward_bound=-6.7
# Iter: 526
# 526: loss=0.267, reward_mean=-6.8, reward_bound=-6.4
# Iter: 527
# 527: loss=0.248, reward_mean=-6.9, reward_bound=-6.6
# Iter: 528
# 528: loss=0.275, reward_mean=-6.7, reward_bound=-6.5
# Iter: 529
# 529: loss=0.287, reward_mean=-6.8, reward_bound=-6.5
# Iter: 530
# 530: loss=0.236, reward_mean=-6.8, reward_bound=-6.5
# Iter: 531
# 531: loss=0.193, reward_mean=-6.8, reward_bound=-6.7
# Iter: 532
# 532: loss=0.271, reward_mean=-6.7, reward_bound=-6.4
# Iter: 533
# 533: loss=0.280, reward_mean=-7.0, reward_bound=-6.7
# Iter: 534
# 534: loss=0.323, reward_mean=-6.8, reward_bound=-6.5
# Iter: 535
# 535: loss=0.202, reward_mean=-7.1, reward_bound=-6.7
# Iter: 536
# 536: loss=0.269, reward_mean=-6.7, reward_bound=-6.4
# Iter: 537
# 537: loss=0.331, reward_mean=-7.1, reward_bound=-6.8
# Iter: 538
# 538: loss=0.208, reward_mean=-7.0, reward_bound=-6.6
# Iter: 539
# 539: loss=0.251, reward_mean=-7.1, reward_bound=-6.8
# Iter: 540
# 540: loss=0.176, reward_mean=-6.8, reward_bound=-6.5
# Iter: 541
# 541: loss=0.244, reward_mean=-7.1, reward_bound=-6.7
# Iter: 542
# 542: loss=0.290, reward_mean=-6.7, reward_bound=-6.4
# Iter: 543
# 543: loss=0.337, reward_mean=-7.0, reward_bound=-6.5
# Iter: 544
# 544: loss=0.223, reward_mean=-6.8, reward_bound=-6.4
# Iter: 545
# 545: loss=0.262, reward_mean=-6.9, reward_bound=-6.6
# Iter: 546
# 546: loss=0.226, reward_mean=-6.9, reward_bound=-6.5
# Iter: 547
# 547: loss=0.222, reward_mean=-6.9, reward_bound=-6.5
# Iter: 548
# 548: loss=0.227, reward_mean=-6.7, reward_bound=-6.3
# Iter: 549
# 549: loss=0.235, reward_mean=-6.7, reward_bound=-6.5
# Iter: 550
# 550: loss=0.338, reward_mean=-7.1, reward_bound=-6.8
# Iter: 551
# 551: loss=0.237, reward_mean=-7.1, reward_bound=-6.9
# Iter: 552
# 552: loss=0.167, reward_mean=-6.7, reward_bound=-6.4
# Iter: 553
# 553: loss=0.219, reward_mean=-6.7, reward_bound=-6.5
# Iter: 554
# 554: loss=0.182, reward_mean=-6.9, reward_bound=-6.4
# Iter: 555
# 555: loss=0.238, reward_mean=-7.0, reward_bound=-6.7
# Iter: 556
# 556: loss=0.292, reward_mean=-6.7, reward_bound=-6.4
# Iter: 557
# 557: loss=0.279, reward_mean=-6.9, reward_bound=-6.4
# Iter: 558
# 558: loss=0.207, reward_mean=-6.9, reward_bound=-6.5
# Iter: 559
# 559: loss=0.202, reward_mean=-6.7, reward_bound=-6.4
# Iter: 560
# 560: loss=0.195, reward_mean=-6.9, reward_bound=-6.5
# Iter: 561
# 561: loss=0.231, reward_mean=-6.8, reward_bound=-6.5
# Iter: 562
# 562: loss=0.176, reward_mean=-6.7, reward_bound=-6.4
# Iter: 563
# 563: loss=0.220, reward_mean=-6.7, reward_bound=-6.4
# Iter: 564
# 564: loss=0.158, reward_mean=-6.6, reward_bound=-6.2
# Iter: 565
# 565: loss=0.228, reward_mean=-6.8, reward_bound=-6.5
# Iter: 566
# 566: loss=0.167, reward_mean=-6.7, reward_bound=-6.4
# Iter: 567
# 567: loss=0.169, reward_mean=-6.8, reward_bound=-6.5
# Iter: 568
# 568: loss=0.173, reward_mean=-6.9, reward_bound=-6.7
# Iter: 569
# 569: loss=0.168, reward_mean=-6.7, reward_bound=-6.5
# Iter: 570
# 570: loss=0.167, reward_mean=-6.9, reward_bound=-6.5
# Iter: 571
# 571: loss=0.151, reward_mean=-7.1, reward_bound=-6.4
# Iter: 572
# 572: loss=0.159, reward_mean=-7.1, reward_bound=-6.6
# Iter: 573
# 573: loss=0.136, reward_mean=-6.9, reward_bound=-6.6
# Iter: 574
# 574: loss=0.199, reward_mean=-7.0, reward_bound=-6.5
# Iter: 575
# 575: loss=0.121, reward_mean=-7.1, reward_bound=-6.6
# Iter: 576
# 576: loss=0.188, reward_mean=-7.0, reward_bound=-6.6
# Iter: 577
# 577: loss=0.128, reward_mean=-7.0, reward_bound=-6.5
# Iter: 578
# 578: loss=0.180, reward_mean=-6.8, reward_bound=-6.4
# Iter: 579
# 579: loss=0.190, reward_mean=-6.8, reward_bound=-6.5
# Iter: 580
# 580: loss=0.154, reward_mean=-6.8, reward_bound=-6.5
# Iter: 581
# 581: loss=0.221, reward_mean=-6.8, reward_bound=-6.4
# Iter: 582
# 582: loss=0.243, reward_mean=-6.9, reward_bound=-6.5
# Iter: 583
# 583: loss=0.151, reward_mean=-6.8, reward_bound=-6.4
# Iter: 584
# 584: loss=0.175, reward_mean=-7.0, reward_bound=-6.9
# Iter: 585
# 585: loss=0.200, reward_mean=-6.7, reward_bound=-6.5
# Iter: 586
# 586: loss=0.270, reward_mean=-6.9, reward_bound=-6.5
# Iter: 587
# 587: loss=0.221, reward_mean=-6.8, reward_bound=-6.5
# Iter: 588
# 588: loss=0.184, reward_mean=-7.0, reward_bound=-6.7
# Iter: 589
# 589: loss=0.156, reward_mean=-6.8, reward_bound=-6.4
# Iter: 590
# 590: loss=0.184, reward_mean=-6.7, reward_bound=-6.4
# Iter: 591
# 591: loss=0.132, reward_mean=-6.9, reward_bound=-6.5
# Iter: 592
# 592: loss=0.119, reward_mean=-6.8, reward_bound=-6.4
# Iter: 593
# 593: loss=0.174, reward_mean=-7.0, reward_bound=-6.6
# Iter: 594
# 594: loss=0.164, reward_mean=-6.8, reward_bound=-6.4
# Iter: 595
# 595: loss=0.146, reward_mean=-6.7, reward_bound=-6.5
# Iter: 596
# 596: loss=0.157, reward_mean=-6.9, reward_bound=-6.6
# Iter: 597
# 597: loss=0.154, reward_mean=-6.9, reward_bound=-6.6
# Iter: 598
# 598: loss=0.144, reward_mean=-6.6, reward_bound=-6.4
# Iter: 599
# 599: loss=0.209, reward_mean=-6.7, reward_bound=-6.4
# Iter: 600
# 600: loss=0.144, reward_mean=-6.8, reward_bound=-6.3
# Iter: 601
# 601: loss=0.224, reward_mean=-6.8, reward_bound=-6.6
# Iter: 602
# 602: loss=0.154, reward_mean=-7.1, reward_bound=-6.6
# Iter: 603
# 603: loss=0.173, reward_mean=-6.9, reward_bound=-6.5
# Iter: 604
# 604: loss=0.214, reward_mean=-6.8, reward_bound=-6.5
# Iter: 605
# 605: loss=0.163, reward_mean=-6.8, reward_bound=-6.4
# Iter: 606
# 606: loss=0.173, reward_mean=-6.8, reward_bound=-6.4
# Iter: 607
# 607: loss=0.226, reward_mean=-6.8, reward_bound=-6.4
# Iter: 608
# 608: loss=0.188, reward_mean=-6.7, reward_bound=-6.5
# Iter: 609
# 609: loss=0.214, reward_mean=-6.8, reward_bound=-6.4
# Iter: 610
# 610: loss=0.110, reward_mean=-6.7, reward_bound=-6.4
# Iter: 611
# 611: loss=0.096, reward_mean=-6.9, reward_bound=-6.5
# Iter: 612
# 612: loss=0.252, reward_mean=-6.9, reward_bound=-6.5
# Iter: 613
# 613: loss=0.131, reward_mean=-7.0, reward_bound=-6.6
# Iter: 614
# 614: loss=0.119, reward_mean=-6.9, reward_bound=-6.5
# Iter: 615
# 615: loss=0.144, reward_mean=-6.9, reward_bound=-6.6
# Iter: 616
# 616: loss=0.200, reward_mean=-6.8, reward_bound=-6.3
# Iter: 617
# 617: loss=0.136, reward_mean=-6.8, reward_bound=-6.5
# Iter: 618
# 618: loss=0.142, reward_mean=-7.1, reward_bound=-6.5
# Iter: 619
# 619: loss=0.170, reward_mean=-6.7, reward_bound=-6.3
# Iter: 620
# 620: loss=0.169, reward_mean=-6.7, reward_bound=-6.5
# Iter: 621
# 621: loss=0.139, reward_mean=-6.7, reward_bound=-6.3
# Iter: 622
# 622: loss=0.206, reward_mean=-6.7, reward_bound=-6.4
# Iter: 623
# 623: loss=0.157, reward_mean=-6.7, reward_bound=-6.5
# Iter: 624
# 624: loss=0.141, reward_mean=-6.9, reward_bound=-6.5
# Iter: 625
# 625: loss=0.105, reward_mean=-6.7, reward_bound=-6.4
# Iter: 626
# 626: loss=0.121, reward_mean=-6.6, reward_bound=-6.4
# Iter: 627
# 627: loss=0.220, reward_mean=-7.2, reward_bound=-6.9
# Iter: 628
# 628: loss=0.135, reward_mean=-6.6, reward_bound=-6.3
# Iter: 629
# 629: loss=0.172, reward_mean=-6.9, reward_bound=-6.4
# Iter: 630
# 630: loss=0.148, reward_mean=-6.7, reward_bound=-6.4
# Iter: 631
# 631: loss=0.124, reward_mean=-6.7, reward_bound=-6.4
# Iter: 632
# 632: loss=0.149, reward_mean=-6.8, reward_bound=-6.6
# Iter: 633
# 633: loss=0.103, reward_mean=-6.6, reward_bound=-6.3
# Iter: 634
# 634: loss=0.147, reward_mean=-6.7, reward_bound=-6.4
# Iter: 635
# 635: loss=0.150, reward_mean=-6.7, reward_bound=-6.3
# Iter: 636
# 636: loss=0.125, reward_mean=-6.8, reward_bound=-6.4
# Iter: 637
# 637: loss=0.172, reward_mean=-6.5, reward_bound=-6.3
# Iter: 638
# 638: loss=0.175, reward_mean=-6.6, reward_bound=-6.3
# Iter: 639
# 639: loss=0.220, reward_mean=-6.6, reward_bound=-6.4
# Iter: 640
# 640: loss=0.092, reward_mean=-6.9, reward_bound=-6.5
# Iter: 641
# 641: loss=0.123, reward_mean=-6.9, reward_bound=-6.5
# Iter: 642
# 642: loss=0.123, reward_mean=-6.8, reward_bound=-6.4
# Iter: 643
# 643: loss=0.192, reward_mean=-6.7, reward_bound=-6.4
# Iter: 644
# 644: loss=0.130, reward_mean=-6.9, reward_bound=-6.6
# Iter: 645
# 645: loss=0.142, reward_mean=-6.6, reward_bound=-6.3
# Iter: 646
# 646: loss=0.147, reward_mean=-6.7, reward_bound=-6.5
# Iter: 647
# 647: loss=0.153, reward_mean=-6.5, reward_bound=-6.3
# Iter: 648
# 648: loss=0.170, reward_mean=-6.7, reward_bound=-6.4
# Iter: 649
# 649: loss=0.141, reward_mean=-6.6, reward_bound=-6.3
# Iter: 650
# 650: loss=0.200, reward_mean=-6.7, reward_bound=-6.4
# Iter: 651
# 651: loss=0.145, reward_mean=-6.6, reward_bound=-6.3
# Iter: 652
# 652: loss=0.120, reward_mean=-6.9, reward_bound=-6.6
# Iter: 653
# 653: loss=0.129, reward_mean=-6.8, reward_bound=-6.4
# Iter: 654
# 654: loss=0.162, reward_mean=-6.7, reward_bound=-6.4
# Iter: 655
# 655: loss=0.124, reward_mean=-6.8, reward_bound=-6.5
# Iter: 656
# 656: loss=0.195, reward_mean=-6.5, reward_bound=-6.4
# Iter: 657
# 657: loss=0.142, reward_mean=-6.7, reward_bound=-6.5
# Iter: 658
# 658: loss=0.139, reward_mean=-7.1, reward_bound=-6.5
# Iter: 659
# 659: loss=0.098, reward_mean=-6.7, reward_bound=-6.5
# Iter: 660
# 660: loss=0.159, reward_mean=-6.7, reward_bound=-6.5
# Iter: 661
# 661: loss=0.125, reward_mean=-6.7, reward_bound=-6.5
# Iter: 662
# 662: loss=0.179, reward_mean=-7.1, reward_bound=-6.9
# Iter: 663
# 663: loss=0.127, reward_mean=-6.7, reward_bound=-6.4
# Iter: 664
# 664: loss=0.141, reward_mean=-6.8, reward_bound=-6.5
# Iter: 665
# 665: loss=0.183, reward_mean=-6.7, reward_bound=-6.4
# Iter: 666
# 666: loss=0.165, reward_mean=-6.8, reward_bound=-6.4
# Iter: 667
# 667: loss=0.174, reward_mean=-6.7, reward_bound=-6.5
# Iter: 668
# 668: loss=0.174, reward_mean=-6.9, reward_bound=-6.7
# Iter: 669
# 669: loss=0.194, reward_mean=-6.8, reward_bound=-6.7
# Iter: 670
# 670: loss=0.185, reward_mean=-7.1, reward_bound=-6.8
# Iter: 671
# 671: loss=0.170, reward_mean=-6.8, reward_bound=-6.4
# Iter: 672
# 672: loss=0.160, reward_mean=-6.8, reward_bound=-6.5
# Iter: 673
# 673: loss=0.114, reward_mean=-6.9, reward_bound=-6.7
# Iter: 674
# 674: loss=0.143, reward_mean=-6.7, reward_bound=-6.5
# Iter: 675
# 675: loss=0.158, reward_mean=-6.8, reward_bound=-6.4
# Iter: 676
# 676: loss=0.247, reward_mean=-7.0, reward_bound=-6.8
# Iter: 677
# 677: loss=0.181, reward_mean=-6.7, reward_bound=-6.4
# Iter: 678
# 678: loss=0.131, reward_mean=-6.8, reward_bound=-6.5
# Iter: 679
# 679: loss=0.167, reward_mean=-6.7, reward_bound=-6.4
# Iter: 680
# 680: loss=0.149, reward_mean=-7.0, reward_bound=-6.6
# Iter: 681
# 681: loss=0.074, reward_mean=-6.9, reward_bound=-6.5
# Iter: 682
# 682: loss=0.071, reward_mean=-7.2, reward_bound=-6.8
# Iter: 683
# 683: loss=0.090, reward_mean=-7.2, reward_bound=-6.9
# Iter: 684
# 684: loss=0.150, reward_mean=-7.3, reward_bound=-6.8
# Iter: 685
# 685: loss=0.098, reward_mean=-7.6, reward_bound=-7.0
# Iter: 686
# 686: loss=0.161, reward_mean=-7.4, reward_bound=-6.6
# Iter: 687
# 687: loss=0.130, reward_mean=-7.4, reward_bound=-6.7
# Iter: 688
# 688: loss=0.092, reward_mean=-6.8, reward_bound=-6.5
# Iter: 689
# 689: loss=0.122, reward_mean=-6.9, reward_bound=-6.5
# Iter: 690
# 690: loss=0.157, reward_mean=-6.7, reward_bound=-6.4
# Iter: 691
# 691: loss=0.117, reward_mean=-6.6, reward_bound=-6.4
# Iter: 692
# 692: loss=0.135, reward_mean=-6.8, reward_bound=-6.5
# Iter: 693
# 693: loss=0.114, reward_mean=-7.0, reward_bound=-6.7
# Iter: 694
# 694: loss=0.176, reward_mean=-6.6, reward_bound=-6.4
# Iter: 695
# 695: loss=0.124, reward_mean=-6.6, reward_bound=-6.3
# Iter: 696
# 696: loss=0.117, reward_mean=-6.7, reward_bound=-6.3
# Iter: 697
# 697: loss=0.167, reward_mean=-6.6, reward_bound=-6.4
# Iter: 698
# 698: loss=0.177, reward_mean=-6.7, reward_bound=-6.5
# Iter: 699
# 699: loss=0.108, reward_mean=-6.8, reward_bound=-6.5
# Iter: 700
# 700: loss=0.171, reward_mean=-6.8, reward_bound=-6.3
# Iter: 701
# 701: loss=0.156, reward_mean=-6.7, reward_bound=-6.4
# Iter: 702
# 702: loss=0.100, reward_mean=-6.6, reward_bound=-6.4
# Iter: 703
# 703: loss=0.122, reward_mean=-6.9, reward_bound=-6.6
# Iter: 704
# 704: loss=0.128, reward_mean=-6.8, reward_bound=-6.7
# Iter: 705
# 705: loss=0.217, reward_mean=-6.8, reward_bound=-6.5
# Iter: 706
# 706: loss=0.152, reward_mean=-6.8, reward_bound=-6.4
# Iter: 707
# 707: loss=0.146, reward_mean=-6.6, reward_bound=-6.4
# Iter: 708
# 708: loss=0.158, reward_mean=-6.9, reward_bound=-6.6
# Iter: 709
# 709: loss=0.083, reward_mean=-6.8, reward_bound=-6.5
# Iter: 710
# 710: loss=0.104, reward_mean=-6.8, reward_bound=-6.5
# Iter: 711
# 711: loss=0.112, reward_mean=-6.9, reward_bound=-6.6
# Iter: 712
# 712: loss=0.082, reward_mean=-7.3, reward_bound=-6.4
# Iter: 713
# 713: loss=0.103, reward_mean=-7.4, reward_bound=-6.8
# Iter: 714
# 714: loss=0.162, reward_mean=-7.2, reward_bound=-6.7
# Iter: 715
# 715: loss=0.099, reward_mean=-6.8, reward_bound=-6.5
# Iter: 716
# 716: loss=0.095, reward_mean=-7.1, reward_bound=-6.7
# Iter: 717
# 717: loss=0.099, reward_mean=-6.9, reward_bound=-6.4
# Iter: 718
# 718: loss=0.181, reward_mean=-6.8, reward_bound=-6.4
# Iter: 719
# 719: loss=0.176, reward_mean=-6.7, reward_bound=-6.5
# Iter: 720
# 720: loss=0.146, reward_mean=-6.5, reward_bound=-6.3
# Iter: 721
# 721: loss=0.187, reward_mean=-6.8, reward_bound=-6.4
# Iter: 722
# 722: loss=0.117, reward_mean=-6.7, reward_bound=-6.4
# Iter: 723
# 723: loss=0.102, reward_mean=-7.1, reward_bound=-6.8
# Iter: 724
# 724: loss=0.208, reward_mean=-6.9, reward_bound=-6.6
# Iter: 725
# 725: loss=0.149, reward_mean=-6.7, reward_bound=-6.5
# Iter: 726
# 726: loss=0.199, reward_mean=-6.9, reward_bound=-6.4
# Iter: 727
# 727: loss=0.142, reward_mean=-6.8, reward_bound=-6.5
# Iter: 728
# 728: loss=0.113, reward_mean=-6.7, reward_bound=-6.5
# Iter: 729
# 729: loss=0.093, reward_mean=-6.6, reward_bound=-6.3
# Iter: 730
# 730: loss=0.135, reward_mean=-6.6, reward_bound=-6.4
# Iter: 731
# 731: loss=0.093, reward_mean=-6.8, reward_bound=-6.4
# Iter: 732
# 732: loss=0.083, reward_mean=-6.8, reward_bound=-6.4
# Iter: 733
# 733: loss=0.086, reward_mean=-7.2, reward_bound=-6.8
# Iter: 734
# 734: loss=0.088, reward_mean=-7.0, reward_bound=-6.6
# Iter: 735
# 735: loss=0.160, reward_mean=-6.9, reward_bound=-6.3
# Iter: 736
# 736: loss=0.115, reward_mean=-7.2, reward_bound=-6.8
# Iter: 737
# 737: loss=0.123, reward_mean=-6.7, reward_bound=-6.4
# Iter: 738
# 738: loss=0.115, reward_mean=-6.8, reward_bound=-6.6
# Iter: 739
# 739: loss=0.150, reward_mean=-6.5, reward_bound=-6.4
# Iter: 740
# 740: loss=0.103, reward_mean=-6.7, reward_bound=-6.4
# Iter: 741
# 741: loss=0.118, reward_mean=-6.8, reward_bound=-6.6
# Iter: 742
# 742: loss=0.081, reward_mean=-6.7, reward_bound=-6.4
# Iter: 743
# 743: loss=0.157, reward_mean=-6.7, reward_bound=-6.3
# Iter: 744
# 744: loss=0.120, reward_mean=-6.7, reward_bound=-6.4
# Iter: 745
# 745: loss=0.105, reward_mean=-6.6, reward_bound=-6.3
# Iter: 746
# 746: loss=0.200, reward_mean=-6.7, reward_bound=-6.4
# Iter: 747
# 747: loss=0.115, reward_mean=-6.8, reward_bound=-6.7
# Iter: 748
# 748: loss=0.135, reward_mean=-6.7, reward_bound=-6.4
# Iter: 749
# 749: loss=0.161, reward_mean=-6.9, reward_bound=-6.6
# Iter: 750
# 750: loss=0.156, reward_mean=-7.0, reward_bound=-6.7
# Iter: 751
# 751: loss=0.082, reward_mean=-6.8, reward_bound=-6.4
# Iter: 752
# 752: loss=0.108, reward_mean=-6.8, reward_bound=-6.5
# Iter: 753
# 753: loss=0.154, reward_mean=-6.8, reward_bound=-6.7
# Iter: 754
# 754: loss=0.114, reward_mean=-6.8, reward_bound=-6.3
# Iter: 755
# 755: loss=0.170, reward_mean=-6.6, reward_bound=-6.4
# Iter: 756
# 756: loss=0.159, reward_mean=-7.0, reward_bound=-6.6
# Iter: 757
# 757: loss=0.125, reward_mean=-7.0, reward_bound=-6.8
# Iter: 758
# 758: loss=0.116, reward_mean=-6.8, reward_bound=-6.6
# Iter: 759
# 759: loss=0.100, reward_mean=-6.7, reward_bound=-6.4
# Iter: 760
# 760: loss=0.150, reward_mean=-6.7, reward_bound=-6.4
# Iter: 761
# 761: loss=0.127, reward_mean=-6.7, reward_bound=-6.4
# Iter: 762
# 762: loss=0.095, reward_mean=-6.8, reward_bound=-6.4
# Iter: 763
# 763: loss=0.138, reward_mean=-6.8, reward_bound=-6.5
# Iter: 764
# 764: loss=0.213, reward_mean=-6.7, reward_bound=-6.4
# ...
# Iter: 1792
# 1792: loss=0.023, reward_mean=-6.5, reward_bound=-6.3
# Iter: 1793
# 1793: loss=0.064, reward_mean=-6.5, reward_bound=-6.3
# Iter: 1794
# 1794: loss=0.038, reward_mean=-6.3, reward_bound=-6.2
# Iter: 1795
# 1795: loss=0.023, reward_mean=-6.6, reward_bound=-6.3
# Iter: 1796
# 1796: loss=0.030, reward_mean=-6.6, reward_bound=-6.3
# Iter: 1797
# 1797: loss=0.024, reward_mean=-6.4, reward_bound=-6.1
# Iter: 1798
# 1798: loss=0.016, reward_mean=-6.6, reward_bound=-6.3
# Iter: 1799
# 1799: loss=0.023, reward_mean=-6.5, reward_bound=-6.1
# Iter: 1800
# 1800: loss=0.023, reward_mean=-6.7, reward_bound=-6.3
# Iter: 1801
# 1801: loss=0.051, reward_mean=-6.7, reward_bound=-6.4
# Iter: 1802
# 1802: loss=0.017, reward_mean=-6.8, reward_bound=-6.3
# Iter: 1803
# 1803: loss=0.012, reward_mean=-6.5, reward_bound=-6.2
# Iter: 1804
# 1804: loss=0.013, reward_mean=-6.4, reward_bound=-6.3
# Iter: 1805
# 1805: loss=0.015, reward_mean=-6.5, reward_bound=-6.2
# Iter: 1806
# 1806: loss=0.018, reward_mean=-6.5, reward_bound=-6.3
# Iter: 1807
# 1807: loss=0.014, reward_mean=-6.5, reward_bound=-6.3
# Iter: 1808
# 1808: loss=0.017, reward_mean=-6.8, reward_bound=-6.3
# Iter: 1809
# 1809: loss=0.024, reward_mean=-6.3, reward_bound=-6.3
# Iter: 1810
# 1810: loss=0.056, reward_mean=-6.4, reward_bound=-6.2
# Iter: 1811
# 1811: loss=0.014, reward_mean=-6.4, reward_bound=-6.3
# Iter: 1812
# 1812: loss=0.019, reward_mean=-6.4, reward_bound=-6.2
# Iter: 1813
# 1813: loss=0.017, reward_mean=-6.6, reward_bound=-6.3
# Iter: 1814
# 1814: loss=0.024, reward_mean=-6.5, reward_bound=-6.3
# Iter: 1815
# 1815: loss=0.015, reward_mean=-6.7, reward_bound=-6.3
# Iter: 1816
# 1816: loss=0.015, reward_mean=-6.6, reward_bound=-6.3
# Iter: 1817
# 1817: loss=0.042, reward_mean=-6.8, reward_bound=-6.4
# Iter: 1818
# 1818: loss=0.012, reward_mean=-6.6, reward_bound=-6.3
# Iter: 1819
# 1819: loss=0.021, reward_mean=-6.7, reward_bound=-6.4
# Iter: 1820
# 1820: loss=0.020, reward_mean=-6.5, reward_bound=-6.2
# Iter: 1821
# 1821: loss=0.012, reward_mean=-6.8, reward_bound=-6.4
# Iter: 1822
# 1822: loss=0.038, reward_mean=-6.8, reward_bound=-6.4
# Iter: 1823
# 1823: loss=0.015, reward_mean=-6.8, reward_bound=-6.3
# Iter: 1824
# 1824: loss=0.016, reward_mean=-6.5, reward_bound=-6.3
# Iter: 1825
# 1825: loss=0.015, reward_mean=-6.4, reward_bound=-6.2
# Iter: 1826
# 1826: loss=0.025, reward_mean=-6.3, reward_bound=-6.2
# Iter: 1827
# 1827: loss=0.021, reward_mean=-6.5, reward_bound=-6.3
# Iter: 1828
# 1828: loss=0.019, reward_mean=-6.5, reward_bound=-6.3
# Iter: 1829
# 1829: loss=0.021, reward_mean=-6.3, reward_bound=-6.3
# Iter: 1830
# 1830: loss=0.015, reward_mean=-6.6, reward_bound=-6.3
# Iter: 1831
# 1831: loss=0.012, reward_mean=-6.8, reward_bound=-6.4
# Iter: 1832
# 1832: loss=0.039, reward_mean=-6.5, reward_bound=-6.4
# Iter: 1833
# 1833: loss=0.028, reward_mean=-6.7, reward_bound=-6.4
# Iter: 1834
# 1834: loss=0.023, reward_mean=-6.6, reward_bound=-6.2
# Iter: 1835
# 1835: loss=0.027, reward_mean=-6.8, reward_bound=-6.4
# Iter: 1836
# 1836: loss=0.026, reward_mean=-7.0, reward_bound=-6.4
# Iter: 1837
# 1837: loss=0.021, reward_mean=-6.8, reward_bound=-6.4
# Iter: 1838
# 1838: loss=0.072, reward_mean=-6.6, reward_bound=-6.3
# Iter: 1839
# 1839: loss=0.068, reward_mean=-6.5, reward_bound=-6.3
# Iter: 1840
# 1840: loss=0.015, reward_mean=-6.4, reward_bound=-6.2
# Iter: 1841
# 1841: loss=0.017, reward_mean=-6.7, reward_bound=-6.1
# Iter: 1842
# 1842: loss=0.024, reward_mean=-6.4, reward_bound=-6.3
# Iter: 1843
# 1843: loss=0.023, reward_mean=-6.4, reward_bound=-6.3
# Iter: 1844
# 1844: loss=0.016, reward_mean=-6.5, reward_bound=-6.3
# Iter: 1845
# 1845: loss=0.020, reward_mean=-6.6, reward_bound=-6.4
# Iter: 1846
# 1846: loss=0.017, reward_mean=-6.8, reward_bound=-6.4
# Iter: 1847
# 1847: loss=0.020, reward_mean=-7.0, reward_bound=-6.4
# Iter: 1848
# 1848: loss=0.044, reward_mean=-6.8, reward_bound=-6.3
# Iter: 1849
# 1849: loss=0.024, reward_mean=-6.5, reward_bound=-6.2
# Iter: 1850
# 1850: loss=0.028, reward_mean=-6.8, reward_bound=-6.4
# Iter: 1851
# 1851: loss=0.016, reward_mean=-6.8, reward_bound=-6.4
# Iter: 1852
# 1852: loss=0.021, reward_mean=-6.5, reward_bound=-6.3
# Iter: 1853
# 1853: loss=0.025, reward_mean=-6.6, reward_bound=-6.3
# Iter: 1854
# 1854: loss=0.011, reward_mean=-6.5, reward_bound=-6.3
# Iter: 1855
# 1855: loss=0.014, reward_mean=-6.6, reward_bound=-6.4
# Iter: 1856
# 1856: loss=0.035, reward_mean=-6.7, reward_bound=-6.5
# Iter: 1857
# 1857: loss=0.020, reward_mean=-6.6, reward_bound=-6.2
# Iter: 1858
# 1858: loss=0.013, reward_mean=-6.4, reward_bound=-6.2
# Iter: 1859
# 1859: loss=0.043, reward_mean=-6.7, reward_bound=-6.5
# Iter: 1860
# 1860: loss=0.029, reward_mean=-6.6, reward_bound=-6.3
# Iter: 1861
# 1861: loss=0.021, reward_mean=-6.7, reward_bound=-6.3
# Iter: 1862
# 1862: loss=0.016, reward_mean=-6.8, reward_bound=-6.4
# Iter: 1863
# 1863: loss=0.018, reward_mean=-6.6, reward_bound=-6.3
# Iter: 1864
# 1864: loss=0.021, reward_mean=-6.6, reward_bound=-6.4
# Iter: 1865
# 1865: loss=0.019, reward_mean=-6.5, reward_bound=-6.2
# Iter: 1866
# 1866: loss=0.012, reward_mean=-6.8, reward_bound=-6.4
# Iter: 1867
# 1867: loss=0.023, reward_mean=-6.3, reward_bound=-6.2
# Iter: 1868
# 1868: loss=0.011, reward_mean=-6.4, reward_bound=-6.3
# Iter: 1869
# 1869: loss=0.029, reward_mean=-6.3, reward_bound=-6.2
# Iter: 1870
# 1870: loss=0.011, reward_mean=-6.4, reward_bound=-6.2
# Iter: 1871
# 1871: loss=0.028, reward_mean=-6.5, reward_bound=-6.4
# Iter: 1872
# 1872: loss=0.023, reward_mean=-6.6, reward_bound=-6.3
# Iter: 1873
# 1873: loss=0.021, reward_mean=-6.5, reward_bound=-6.6
# Iter: 1874
# 1874: loss=0.024, reward_mean=-6.4, reward_bound=-6.3
# Iter: 1875
# 1875: loss=0.010, reward_mean=-6.5, reward_bound=-6.3
# Iter: 1876
# 1876: loss=0.016, reward_mean=-6.3, reward_bound=-6.1
# Iter: 1877
# 1877: loss=0.010, reward_mean=-6.7, reward_bound=-6.3
# Iter: 1878
# 1878: loss=0.015, reward_mean=-6.5, reward_bound=-6.2
# Iter: 1879
# 1879: loss=0.023, reward_mean=-6.9, reward_bound=-6.4
# Iter: 1880
# 1880: loss=0.019, reward_mean=-6.5, reward_bound=-6.3
# Iter: 1881
# 1881: loss=0.014, reward_mean=-6.4, reward_bound=-6.3
# Iter: 1882
# 1882: loss=0.020, reward_mean=-6.6, reward_bound=-6.2
# Iter: 1883
# 1883: loss=0.015, reward_mean=-6.6, reward_bound=-6.3
# Iter: 1884
# 1884: loss=0.014, reward_mean=-6.6, reward_bound=-6.3
# Iter: 1885
# 1885: loss=0.033, reward_mean=-6.6, reward_bound=-6.4
# Iter: 1886
# 1886: loss=0.023, reward_mean=-6.3, reward_bound=-6.2
# Iter: 1887
# 1887: loss=0.011, reward_mean=-6.7, reward_bound=-6.3
# Iter: 1888
# 1888: loss=0.030, reward_mean=-7.1, reward_bound=-6.6
# Iter: 1889
# 1889: loss=0.051, reward_mean=-6.3, reward_bound=-6.1
# Iter: 1890
# 1890: loss=0.013, reward_mean=-6.7, reward_bound=-6.4
# Iter: 1891
# 1891: loss=0.025, reward_mean=-6.7, reward_bound=-6.3
# Iter: 1892
# 1892: loss=0.014, reward_mean=-6.4, reward_bound=-6.2
# Iter: 1893
# 1893: loss=0.014, reward_mean=-6.6, reward_bound=-6.3
# Iter: 1894
# 1894: loss=0.013, reward_mean=-6.6, reward_bound=-6.2
# Iter: 1895
# 1895: loss=0.017, reward_mean=-6.4, reward_bound=-6.1
# Iter: 1896
# 1896: loss=0.012, reward_mean=-6.4, reward_bound=-6.2
# Iter: 1897
# 1897: loss=0.017, reward_mean=-6.4, reward_bound=-6.2
# Iter: 1898
# 1898: loss=0.027, reward_mean=-6.3, reward_bound=-6.2
# Iter: 1899
# 1899: loss=0.027, reward_mean=-6.8, reward_bound=-6.4
# Iter: 1900
# 1900: loss=0.017, reward_mean=-6.7, reward_bound=-6.4
# Iter: 1901
# 1901: loss=0.016, reward_mean=-6.5, reward_bound=-6.3
# Iter: 1902
# 1902: loss=0.015, reward_mean=-6.4, reward_bound=-6.2
# Iter: 1903
# 1903: loss=0.021, reward_mean=-6.6, reward_bound=-6.3
# Iter: 1904
# 1904: loss=0.010, reward_mean=-6.7, reward_bound=-6.2
# Iter: 1905
# 1905: loss=0.008, reward_mean=-6.7, reward_bound=-6.3
# Iter: 1906
# 1906: loss=0.020, reward_mean=-6.5, reward_bound=-6.3
# Iter: 1907
# 1907: loss=0.023, reward_mean=-6.5, reward_bound=-6.3
# Iter: 1908
# 1908: loss=0.014, reward_mean=-6.4, reward_bound=-6.2
# Iter: 1909
# 1909: loss=0.010, reward_mean=-6.7, reward_bound=-6.3
# Iter: 1910
# 1910: loss=0.020, reward_mean=-6.6, reward_bound=-6.3
# Iter: 1911
# 1911: loss=0.018, reward_mean=-6.7, reward_bound=-6.3
# Iter: 1912
# 1912: loss=0.020, reward_mean=-6.6, reward_bound=-6.2
# Iter: 1913
# 1913: loss=0.010, reward_mean=-6.6, reward_bound=-6.3
# Iter: 1914
# 1914: loss=0.026, reward_mean=-6.4, reward_bound=-6.2
# Iter: 1915
# 1915: loss=0.017, reward_mean=-6.5, reward_bound=-6.3
# Iter: 1916
# 1916: loss=0.023, reward_mean=-6.5, reward_bound=-6.4
# Iter: 1917
# 1917: loss=0.013, reward_mean=-6.4, reward_bound=-6.3
# Iter: 1918
# 1918: loss=0.010, reward_mean=-6.7, reward_bound=-6.3
# Iter: 1919
# 1919: loss=0.021, reward_mean=-6.4, reward_bound=-6.2
# Iter: 1920
# 1920: loss=0.013, reward_mean=-6.7, reward_bound=-6.3
# Iter: 1921
# 1921: loss=0.008, reward_mean=-6.6, reward_bound=-6.2
# Iter: 1922
# 1922: loss=0.014, reward_mean=-6.7, reward_bound=-6.3
# Iter: 1923
# 1923: loss=0.018, reward_mean=-6.5, reward_bound=-6.4
# Iter: 1924
# 1924: loss=0.011, reward_mean=-6.8, reward_bound=-6.5
# Iter: 1925
# 1925: loss=0.015, reward_mean=-6.9, reward_bound=-6.4
# Iter: 1926
# 1926: loss=0.015, reward_mean=-6.6, reward_bound=-6.2
# Iter: 1927
# 1927: loss=0.021, reward_mean=-6.6, reward_bound=-6.3
# Iter: 1928
# 1928: loss=0.021, reward_mean=-6.9, reward_bound=-6.4
# Iter: 1929
# 1929: loss=0.014, reward_mean=-6.7, reward_bound=-6.3
# Iter: 1930
# 1930: loss=0.023, reward_mean=-6.4, reward_bound=-6.3
# Iter: 1931
# 1931: loss=0.013, reward_mean=-6.6, reward_bound=-6.3
# Iter: 1932
# 1932: loss=0.044, reward_mean=-6.6, reward_bound=-6.4
# Iter: 1933
# 1933: loss=0.019, reward_mean=-6.4, reward_bound=-6.2
# Iter: 1934
# 1934: loss=0.020, reward_mean=-6.6, reward_bound=-6.3
# Iter: 1935
# 1935: loss=0.025, reward_mean=-6.5, reward_bound=-6.3
# Iter: 1936
# 1936: loss=0.010, reward_mean=-6.6, reward_bound=-6.2
# Iter: 1937
# 1937: loss=0.023, reward_mean=-6.5, reward_bound=-6.2
# Iter: 1938
# 1938: loss=0.009, reward_mean=-6.6, reward_bound=-6.4
# Iter: 1939
# 1939: loss=0.030, reward_mean=-6.7, reward_bound=-6.2
# Iter: 1940
# 1940: loss=0.026, reward_mean=-6.9, reward_bound=-6.5
# Iter: 1941
# 1941: loss=0.010, reward_mean=-6.5, reward_bound=-6.4
# Iter: 1942
# 1942: loss=0.019, reward_mean=-6.6, reward_bound=-6.3
# Iter: 1943
# 1943: loss=0.020, reward_mean=-6.4, reward_bound=-6.3
# Iter: 1944
# 1944: loss=0.017, reward_mean=-6.5, reward_bound=-6.3
# Iter: 1945
# 1945: loss=0.016, reward_mean=-6.9, reward_bound=-6.6
# Iter: 1946
# 1946: loss=0.015, reward_mean=-6.6, reward_bound=-6.4
# Iter: 1947
# 1947: loss=0.020, reward_mean=-6.6, reward_bound=-6.3
# Iter: 1948
# 1948: loss=0.014, reward_mean=-6.6, reward_bound=-6.3
# Iter: 1949
# 1949: loss=0.013, reward_mean=-6.5, reward_bound=-6.3
# Iter: 1950
# 1950: loss=0.007, reward_mean=-6.4, reward_bound=-6.1
# Iter: 1951
# 1951: loss=0.006, reward_mean=-6.5, reward_bound=-6.3
# Iter: 1952
# 1952: loss=0.021, reward_mean=-6.5, reward_bound=-6.3
# Iter: 1953
# 1953: loss=0.007, reward_mean=-6.8, reward_bound=-6.2
# Iter: 1954
# 1954: loss=0.015, reward_mean=-6.7, reward_bound=-6.3
# Iter: 1955
# 1955: loss=0.031, reward_mean=-6.5, reward_bound=-6.3
# Iter: 1956
# 1956: loss=0.009, reward_mean=-6.5, reward_bound=-6.2
# Iter: 1957
# 1957: loss=0.010, reward_mean=-6.7, reward_bound=-6.4
# Iter: 1958
# 1958: loss=0.012, reward_mean=-6.5, reward_bound=-6.3
# Iter: 1959
# 1959: loss=0.012, reward_mean=-6.5, reward_bound=-6.2
# Iter: 1960
# 1960: loss=0.024, reward_mean=-6.6, reward_bound=-6.3
# Iter: 1961
# 1961: loss=0.011, reward_mean=-6.4, reward_bound=-6.2
# Iter: 1962
# 1962: loss=0.012, reward_mean=-6.5, reward_bound=-6.3
# Iter: 1963
# 1963: loss=0.018, reward_mean=-6.5, reward_bound=-6.2
# Iter: 1964
# 1964: loss=0.023, reward_mean=-6.6, reward_bound=-6.4
# Iter: 1965
# 1965: loss=0.010, reward_mean=-6.6, reward_bound=-6.4
# Iter: 1966
# 1966: loss=0.023, reward_mean=-6.6, reward_bound=-6.2
# Iter: 1967
# 1967: loss=0.050, reward_mean=-6.4, reward_bound=-6.3
# Iter: 1968
# 1968: loss=0.011, reward_mean=-6.4, reward_bound=-6.3
# Iter: 1969
# 1969: loss=0.025, reward_mean=-6.5, reward_bound=-6.1
# Iter: 1970
# 1970: loss=0.012, reward_mean=-6.6, reward_bound=-6.2
# Iter: 1971
# 1971: loss=0.014, reward_mean=-6.7, reward_bound=-6.4
# Iter: 1972
# 1972: loss=0.083, reward_mean=-6.6, reward_bound=-6.3
# Iter: 1973
# 1973: loss=0.022, reward_mean=-6.8, reward_bound=-6.3
# Iter: 1974
# 1974: loss=0.012, reward_mean=-6.8, reward_bound=-6.3
# Iter: 1975
# 1975: loss=0.059, reward_mean=-6.8, reward_bound=-6.4
# Iter: 1976
# 1976: loss=0.010, reward_mean=-6.8, reward_bound=-6.4
# Iter: 1977
# 1977: loss=0.024, reward_mean=-6.5, reward_bound=-6.4
# Iter: 1978
# 1978: loss=0.014, reward_mean=-6.7, reward_bound=-6.3
# Iter: 1979
# 1979: loss=0.012, reward_mean=-6.7, reward_bound=-6.3
# Iter: 1980
# 1980: loss=0.012, reward_mean=-6.7, reward_bound=-6.3
# Iter: 1981
# 1981: loss=0.011, reward_mean=-6.6, reward_bound=-6.3
# Iter: 1982
# 1982: loss=0.012, reward_mean=-6.4, reward_bound=-6.1
# Iter: 1983
# 1983: loss=0.033, reward_mean=-6.6, reward_bound=-6.3
# Iter: 1984
# 1984: loss=0.011, reward_mean=-6.5, reward_bound=-6.4
# Iter: 1985
# 1985: loss=0.022, reward_mean=-6.5, reward_bound=-6.3
# Iter: 1986
# 1986: loss=0.019, reward_mean=-6.5, reward_bound=-6.3
# Iter: 1987
# 1987: loss=0.033, reward_mean=-6.5, reward_bound=-6.4
# Iter: 1988
# 1988: loss=0.018, reward_mean=-6.4, reward_bound=-6.3
# Iter: 1989
# 1989: loss=0.009, reward_mean=-6.6, reward_bound=-6.3
# Iter: 1990
# 1990: loss=0.012, reward_mean=-6.4, reward_bound=-6.2
# Iter: 1991
# 1991: loss=0.024, reward_mean=-6.6, reward_bound=-6.4
# Iter: 1992
# 1992: loss=0.014, reward_mean=-6.4, reward_bound=-6.2
# Iter: 1993
# 1993: loss=0.031, reward_mean=-6.4, reward_bound=-6.3
# Iter: 1994
# 1994: loss=0.009, reward_mean=-6.6, reward_bound=-6.3
# Iter: 1995
# 1995: loss=0.007, reward_mean=-6.6, reward_bound=-6.3
# Iter: 1996
# 1996: loss=0.014, reward_mean=-6.4, reward_bound=-6.2
# Iter: 1997
# 1997: loss=0.015, reward_mean=-6.8, reward_bound=-6.4
# Iter: 1998
# 1998: loss=0.022, reward_mean=-6.7, reward_bound=-6.3
# Iter: 1999
# 1999: loss=0.016, reward_mean=-6.5, reward_bound=-6.3
# Iter: 2000
# 2000: loss=0.015, reward_mean=-6.6, reward_bound=-6.3
# Iter: 2001
# 2001: loss=0.019, reward_mean=-6.3, reward_bound=-6.2
# Iter: 2002
# 2002: loss=0.010, reward_mean=-6.5, reward_bound=-6.2
# Iter: 2003
# 2003: loss=0.013, reward_mean=-6.4, reward_bound=-6.3
# Iter: 2004
# 2004: loss=0.024, reward_mean=-6.6, reward_bound=-6.3
# Iter: 2005
# 2005: loss=0.023, reward_mean=-6.5, reward_bound=-6.2
# Iter: 2006
# 2006: loss=0.053, reward_mean=-6.6, reward_bound=-6.2
# Iter: 2007
# 2007: loss=0.013, reward_mean=-6.4, reward_bound=-6.3
# Iter: 2008
# 2008: loss=0.011, reward_mean=-6.5, reward_bound=-6.2
# Iter: 2009
# 2009: loss=0.017, reward_mean=-6.6, reward_bound=-6.3
# Iter: 2010
# 2010: loss=0.015, reward_mean=-6.7, reward_bound=-6.2
# Iter: 2011
# 2011: loss=0.015, reward_mean=-6.3, reward_bound=-6.1
# Iter: 2012
# 2012: loss=0.013, reward_mean=-6.5, reward_bound=-6.2
# Iter: 2013
# 2013: loss=0.020, reward_mean=-6.6, reward_bound=-6.3
# Iter: 2014
# 2014: loss=0.037, reward_mean=-6.6, reward_bound=-6.2
# Iter: 2015
# 2015: loss=0.020, reward_mean=-6.8, reward_bound=-6.2
# Iter: 2016
# 2016: loss=0.017, reward_mean=-6.6, reward_bound=-6.3
# Iter: 2017
# 2017: loss=0.014, reward_mean=-6.8, reward_bound=-6.4
# Iter: 2018
# 2018: loss=0.012, reward_mean=-6.5, reward_bound=-6.4
# Iter: 2019
# 2019: loss=0.009, reward_mean=-6.3, reward_bound=-6.0
# Iter: 2020
# 2020: loss=0.007, reward_mean=-6.5, reward_bound=-6.3
# Iter: 2021
# 2021: loss=0.017, reward_mean=-6.6, reward_bound=-6.3
# Iter: 2022
# 2022: loss=0.074, reward_mean=-6.4, reward_bound=-6.2
# Iter: 2023
# 2023: loss=0.014, reward_mean=-6.9, reward_bound=-6.3
# Iter: 2024
# 2024: loss=0.016, reward_mean=-6.8, reward_bound=-6.4
# Iter: 2025
# 2025: loss=0.025, reward_mean=-6.7, reward_bound=-6.3
# Iter: 2026
# 2026: loss=0.035, reward_mean=-6.8, reward_bound=-6.4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-5dfd80708adb> in <module>()
#       3 optimizer = optim.Adam(params=net.parameters(), lr=0.01)
#       4
# ----> 5 for iter_no, batch in enumerate(iterate_batches(net, BATCH_SIZE)):
#       6     print("Iter: {}".format(iter_no))
#       7     obs_v, acts_v, reward_b, reward_m = filter_batch(batch, PERCENTILE)
#
# <ipython-input-8-633329cdb266> in iterate_batches(net, batch_size)
#      29                 batch = []
#      30         obs = next_obs
# ---> 31         time.sleep(0.005)
#      32
#      33
#
# KeyboardInterrupt:
